# %%
# ! pip install -r requirements.txt

# %% [markdown]
# ## Pre-procesamiento
#
# Se realiza una exploración inicial y pre-procesamiento de los datos a analizar:

# %%
import itertools
import re

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from matplotlib.ticker import FuncFormatter
from pandas.api.types import CategoricalDtype
from scipy.stats import expon

# %%
url ='https://raw.githubusercontent.com/DiploDatos/AnalisisyVisualizacion/master/sysarmy_survey_2022_processed.csv'
df = pd.read_csv(url)
df.head()
# Out:
#   work_country work_province work_dedication             work_contract_type
# 0    Argentina     Catamarca       Full-Time      Staff (planta permanente)  \
# 1    Argentina         Chaco       Full-Time  Remoto (empresa de otro país)
# 2    Argentina         Chaco       Full-Time      Staff (planta permanente)
# 3    Argentina         Chaco       Full-Time  Remoto (empresa de otro país)
# 4    Argentina         Chaco       Full-Time      Staff (planta permanente)
#
#    salary_monthly_BRUTO  salary_monthly_NETO  numero
# 0              300000.0             245000.0    True  \
# 1              900000.0             850000.0    True
# 2              120000.0             115000.0    True
# 3              440000.0                  0.0    True
# 4              140000.0             125000.0    True
#
#                       salary_in_usd salary_last_dollar_value
# 0                               NaN                      NaN  \
# 1  Cobro todo el salario en dólares                      300
# 2                               NaN                      NaN
# 3  Cobro todo el salario en dólares                      220
# 4                               NaN                      NaN
#
#                      salary_pay_cripto  ... profile_studies_level_state
# 0                                  NaN  ...                    Completo  \
# 1                                  NaN  ...                         NaN
# 2                                  NaN  ...                         NaN
# 3  Cobro todo el salario criptomonedas  ...                         NaN
# 4                                  NaN  ...                         NaN
#
#                                   profile_career           profile_university
# 0  Licenciatura en redes y comunicación de datos  UP - Universidad de Palermo  \
# 1                                            NaN                          NaN
# 2                                            NaN                          NaN
# 3                                            NaN                          NaN
# 4                                            NaN                          NaN
#
#   profile_boot_camp profile_boot_camp_carrer work_on_call_duty
# 0               NaN                      NaN               NaN  \
# 1               NaN                      NaN               NaN
# 2               NaN                      NaN               NaN
# 3               NaN                      NaN               NaN
# 4               NaN                      NaN               NaN
#
#    salary_on_call_duty_charge work_on_call_duty_charge_type  profile_age
# 0                         NaN                           NaN           35  \
# 1                         NaN                           NaN           31
# 2                         NaN                           NaN           27
# 3                         NaN                           NaN           21
# 4                         NaN                           NaN           32
#
#   profile_gender
# 0      Varón Cis
# 1      Varón Cis
# 2      Varón Cis
# 3      Varón Cis
# 4      Varón Cis
#
# [5 rows x 44 columns]

# %%
pd.set_option('display.float_format', lambda x: '%.5f' % x)  # suppress scientific notation

# %%
df.describe(include='all')
# Out:
#        work_country                    work_province work_dedication
# count          5358                             5358            5358  \
# unique            1                               24               2
# top       Argentina  Ciudad Autónoma de Buenos Aires       Full-Time
# freq           5358                             2699            5106
# mean            NaN                              NaN             NaN
# std             NaN                              NaN             NaN
# min             NaN                              NaN             NaN
# 25%             NaN                              NaN             NaN
# 50%             NaN                              NaN             NaN
# 75%             NaN                              NaN             NaN
# max             NaN                              NaN             NaN
#
#                work_contract_type  salary_monthly_BRUTO  salary_monthly_NETO
# count                        5358            5358.00000           5358.00000  \
# unique                          5                   NaN                  NaN
# top     Staff (planta permanente)                   NaN                  NaN
# freq                         4068                   NaN                  NaN
# mean                          NaN          363510.54282         277010.78680
# std                           NaN          543925.45885         401942.29874
# min                           NaN               0.00000              0.00000
# 25%                           NaN          150000.00000         118612.18750
# 50%                           NaN          256000.00000         201000.00000
# 75%                           NaN          412657.00000         294000.00000
# max                           NaN        28000000.00000       15000000.00000
#
#        numero                       salary_in_usd salary_last_dollar_value
# count    5358                                1640                     1063  \
# unique      1                                   3                      359
# top      True  Cobro parte del salario en dólares                      130
# freq     5358                                 663                       50
# mean      NaN                                 NaN                      NaN
# std       NaN                                 NaN                      NaN
# min       NaN                                 NaN                      NaN
# 25%       NaN                                 NaN                      NaN
# 50%       NaN                                 NaN                      NaN
# 75%       NaN                                 NaN                      NaN
# max       NaN                                 NaN                      NaN
#
#                           salary_pay_cripto  ... profile_studies_level_state
# count                                   161  ...                        2659  \
# unique                                    2  ...                           3
# top     Cobro todo el salario criptomonedas  ...                    Completo
# freq                                    100  ...                        1204
# mean                                    NaN  ...                         NaN
# std                                     NaN  ...                         NaN
# min                                     NaN  ...                         NaN
# 25%                                     NaN  ...                         NaN
# 50%                                     NaN  ...                         NaN
# 75%                                     NaN  ...                         NaN
# max                                     NaN  ...                         NaN
#
#                                profile_career
# count                                    2556  \
# unique                                    391
# top     Ingeniería en Sistemas de Información
# freq                                      452
# mean                                      NaN
# std                                       NaN
# min                                       NaN
# 25%                                       NaN
# 50%                                       NaN
# 75%                                       NaN
# max                                       NaN
#
#                             profile_university profile_boot_camp
# count                                     2502               693  \
# unique                                     450               215
# top     UTN - Universidad Tecnológica Nacional                No
# freq                                       586               185
# mean                                       NaN               NaN
# std                                        NaN               NaN
# min                                        NaN               NaN
# 25%                                        NaN               NaN
# 50%                                        NaN               NaN
# 75%                                        NaN               NaN
# max                                        NaN               NaN
#
#        profile_boot_camp_carrer work_on_call_duty  salary_on_call_duty_charge
# count                       437              1718                  1718.00000  \
# unique                      290                 3                         NaN
# top                          no                No                         NaN
# freq                         38              1166                         NaN
# mean                        NaN               NaN                  2206.67369
# std                         NaN               NaN                 17389.85329
# min                         NaN               NaN                     0.00000
# 25%                         NaN               NaN                     0.00000
# 50%                         NaN               NaN                     0.00000
# 75%                         NaN               NaN                     0.00000
# max                         NaN               NaN                450000.00000
#
#         work_on_call_duty_charge_type  profile_age profile_gender
# count                            1718   5358.00000           5358
# unique                              3          NaN             14
# top     Porcentaje de mi sueldo bruto          NaN      Varón Cis
# freq                             1064          NaN           3902
# mean                              NaN     33.27940            NaN
# std                               NaN      7.92473            NaN
# min                               NaN     18.00000            NaN
# 25%                               NaN     27.00000            NaN
# 50%                               NaN     32.00000            NaN
# 75%                               NaN     38.00000            NaN
# max                               NaN     74.00000            NaN
#
# [11 rows x 44 columns]

# %%
df.columns
# Out:
# Index(['work_country', 'work_province', 'work_dedication',
#        'work_contract_type', 'salary_monthly_BRUTO', 'salary_monthly_NETO',
#        'numero', 'salary_in_usd', 'salary_last_dollar_value',
#        'salary_pay_cripto', 'salary_%_cripto', 'salary_has_bonus',
#        'salary_bonus_tied_to', 'salary_inflation_adjustment',
#        'salary_percentage_inflation_adjustment',
#        'salary_month_last_inflation_adjustment',
#        'salary_comparison_last_semester', 'salary_benefit',
#        'salary_satisfaction', 'Trabajo de', 'profile_years_experience',
#        'work_years_in_company', 'work_years_in_current_position',
#        'work_people_in_charge_of', 'tools_platform',
#        'tools_programming_languages', 'tools_frameworks', 'tools_data_bases',
#        'tools_qa_testing', 'company_employee_number', 'work_work_modality',
#        'Si trabajas bajo un esquema híbrido ¿Cuántos días a la semana vas a la oficina?',
#        'company_recommended', 'profile_studies_level',
#        'profile_studies_level_state', 'profile_career', 'profile_university',
#        'profile_boot_camp', 'profile_boot_camp_carrer', 'work_on_call_duty',
#        'salary_on_call_duty_charge', 'work_on_call_duty_charge_type',
#        'profile_age', 'profile_gender'],
#       dtype='object')

# %% [markdown]
# Se renombran algunas columnas a fin de acceder a cada columna con la sintaxis de un método del objeto `DataFrae` y de acercar el código a las buenas prácticas de programación con Python:

# %%
df = df.rename(columns = {
    'salary_monthly_BRUTO': 'monthly_gross_salary',
    'salary_monthly_NETO': 'monthly_net_salary',
    'salary_%_cripto': 'crypto_salary_percentage',
    'Trabajo de': 'role',
    'Si trabajas bajo un esquema híbrido ¿Cuántos días a la semana vas a la oficina?': 'hybrid_office_days_per_week',
    'profile_studies_level': 'profile_level_study',
})

# %%
df.columns
# Out:
# Index(['work_country', 'work_province', 'work_dedication',
#        'work_contract_type', 'monthly_gross_salary', 'monthly_net_salary',
#        'numero', 'salary_in_usd', 'salary_last_dollar_value',
#        'salary_pay_cripto', 'crypto_salary_percentage', 'salary_has_bonus',
#        'salary_bonus_tied_to', 'salary_inflation_adjustment',
#        'salary_percentage_inflation_adjustment',
#        'salary_month_last_inflation_adjustment',
#        'salary_comparison_last_semester', 'salary_benefit',
#        'salary_satisfaction', 'role', 'profile_years_experience',
#        'work_years_in_company', 'work_years_in_current_position',
#        'work_people_in_charge_of', 'tools_platform',
#        'tools_programming_languages', 'tools_frameworks', 'tools_data_bases',
#        'tools_qa_testing', 'company_employee_number', 'work_work_modality',
#        'hybrid_office_days_per_week', 'company_recommended',
#        'profile_level_study', 'profile_studies_level_state', 'profile_career',
#        'profile_university', 'profile_boot_camp', 'profile_boot_camp_carrer',
#        'work_on_call_duty', 'salary_on_call_duty_charge',
#        'work_on_call_duty_charge_type', 'profile_age', 'profile_gender'],
#       dtype='object')

# %% [markdown]
# ### Columnas de interés (ejercicio 2, item 1)
#
# Las columnas propuestas para este análisis corresponden a:
#
#     - `monthly_gross_salary`
#     - `monthly_net_salary`
#     - `tools_programming_languages`
#         - `profile_years_experience`
#         - `profile_gender`
#         - `tools_platform`
#         - `tools_programming_languages`
#         - `tools_frameworks`
#         - `tools_data_bases`
#         - `tools_qa_testing`
#         - `profile_level_study`
#     - `work_dedication`
#     - `monthly_gross_salary`
#     - `monthly_net_salary`
#     - `salary_comparison_last_semester`
#
# > Sería interesante tener información sobre el rol de las personas encuestadas, pero dicha columna no tiene datos normalizados, parece provenir de un campo de texto libre, y además de resultar compleja la normalización y agrupación, se perderían muchas respuestas.

# %%
columns_of_interest = ['work_dedication',
                       'monthly_gross_salary',
                       'monthly_net_salary',
                       'salary_comparison_last_semester',
                       'profile_years_experience',
                       'tools_platform',
                       'tools_programming_languages',
                       'tools_frameworks',
                       'tools_data_bases',
                       'tools_qa_testing',
                       'profile_level_study',
                       'profile_gender',]

# %%
df = df[columns_of_interest]
df.head()
# Out:
#   work_dedication  monthly_gross_salary  monthly_net_salary
# 0       Full-Time          300000.00000        245000.00000  \
# 1       Full-Time          900000.00000        850000.00000
# 2       Full-Time          120000.00000        115000.00000
# 3       Full-Time          440000.00000             0.00000
# 4       Full-Time          140000.00000        125000.00000
#
#    salary_comparison_last_semester  profile_years_experience
# 0                                2                  10.00000  \
# 1                                4                   2.00000
# 2                                2                   2.00000
# 3                                3                   1.00000
# 4                                2                   1.00000
#
#                        tools_platform
# 0  Amazon Web Services, Linux, VMWare  \
# 1                 Amazon Web Services
# 2                 Amazon Web Services
# 3                Firebase, Serverless
# 4                 Amazon Web Services
#
#                     tools_programming_languages           tools_frameworks
# 0                                        Python  Ninguno de los anteriores  \
# 1  CSS, HTML, Java, Javascript, SQL, TypeScript                   React.js
# 2                       Javascript, PHP, Python     Flask, Laravel, Vue.js
# 3                        Javascript, TypeScript          Node.js, React.js
# 4                         CSS, HTML, Javascript                   React.js
#
#          tools_data_bases                 tools_qa_testing
# 0           ElasticSearch  Postman, Visual Studio Coded UI  \
# 1              PostgreSQL                          Cypress
# 2                 MariaDB        Ninguna de las anteriores
# 3  ElasticSearch, MongoDB        Ninguna de las anteriores
# 4                   MySQL        Ninguna de las anteriores
#
#   profile_level_study profile_gender
# 0       Universitario      Varón Cis
# 1                 NaN      Varón Cis
# 2                 NaN      Varón Cis
# 3                 NaN      Varón Cis
# 4                 NaN      Varón Cis

# %%
df.shape
# Out:
# (5358, 12)

# %% [markdown]
# ### Histogramas exploratorios
#
# Se visualizan los datos de salarios y sus correspondientes frecuencias de respuesta entre las personas encuestadas,
# usando como instrumento algunos estadísticos elementales:
#
# - media
# - varianza
# - percentiles

# %%
def human_format(num, pos=1):
    """
    human formatting for big numbers
    """
    magnitude = 0
    while abs(num) >= 1000:
        magnitude += 1
        num /= 1000.0
    return "%.0f%s" % (num, ["", "K", "M", "G", "T", "P"][magnitude])


FORMATTER = FuncFormatter(human_format)

# %%
FIGSIZE, VSUBPLOTS_FIGSIZE, HSUBPLOTS_FIGSIZE, DPI = (12, 5), (15, 5), (15, 4), 100
PASTEL_PALETTE = sns.color_palette('pastel')
MAIN_PALETTE = itertools.cycle(PASTEL_PALETTE)
CATEGORICAL_PALETTE = sns.color_palette('Set2')
SECUENTIAL_PALETTE = sns.color_palette('flare')

statistics_of_interest = ['mean', 'std', '25%', '50%', '75%']

# %% [markdown]
# #### Histograma salario neto vs salario bruto

# %%
f, ax = plt.subplots(2, 1, figsize=HSUBPLOTS_FIGSIZE, dpi=DPI, sharex=True)
n_bins = 1000, 500

for i, salary in enumerate(['monthly_gross_salary', 'monthly_net_salary']):
    df_to_plot = df[salary]
    sns.histplot(df_to_plot, 
                 bins=n_bins[i],
                 ax=ax[i],
                 label=salary.replace('_', ' '),
                 color=next(MAIN_PALETTE),
                edgecolor='black')
    
    statistics = df_to_plot.describe(include='all')

    for j, name in enumerate(['mean', 'std']):
        statistic = statistics[name]
        ax[i].axvline(statistic,
                      label=f'{name}: {human_format(statistic)}',
                      color=CATEGORICAL_PALETTE.as_hex()[-j],
                      linestyle='dashed')
        
    for j, st in enumerate(['25%', '50%', '75%']):
        statistic = statistics[st]
        ax[i].axvline(statistic,
                      label=f'{st}: {human_format(statistic)}',
                      color=SECUENTIAL_PALETTE.as_hex()[j],
                      linestyle='dashed')
        
    ax[i].xaxis.set_major_formatter(FORMATTER)
    ax[i].grid(alpha=0.3)
    ax[i].legend()
        


plt.xlim(0, statistics['75%'] * 4)
plt.xlabel('salary in ARS')
plt.tight_layout()

# %%
df.describe(include='all').style.format(
    {'monthly_gross_salary': '${:,.2f}',
     'monthly_net_salary': '${:,.2f}'},
    precision=2,
    na_rep='missing'
).highlight_null(color='gray')
# Out:
# <style type="text/css">
# #T_6c799_row1_col1, #T_6c799_row1_col2, #T_6c799_row1_col3, #T_6c799_row1_col4, #T_6c799_row2_col1, #T_6c799_row2_col2, #T_6c799_row2_col3, #T_6c799_row2_col4, #T_6c799_row3_col1, #T_6c799_row3_col2, #T_6c799_row3_col3, #T_6c799_row3_col4, #T_6c799_row4_col0, #T_6c799_row4_col5, #T_6c799_row4_col6, #T_6c799_row4_col7, #T_6c799_row4_col8, #T_6c799_row4_col9, #T_6c799_row4_col10, #T_6c799_row4_col11, #T_6c799_row5_col0, #T_6c799_row5_col5, #T_6c799_row5_col6, #T_6c799_row5_col7, #T_6c799_row5_col8, #T_6c799_row5_col9, #T_6c799_row5_col10, #T_6c799_row5_col11, #T_6c799_row6_col0, #T_6c799_row6_col5, #T_6c799_row6_col6, #T_6c799_row6_col7, #T_6c799_row6_col8, #T_6c799_row6_col9, #T_6c799_row6_col10, #T_6c799_row6_col11, #T_6c799_row7_col0, #T_6c799_row7_col5, #T_6c799_row7_col6, #T_6c799_row7_col7, #T_6c799_row7_col8, #T_6c799_row7_col9, #T_6c799_row7_col10, #T_6c799_row7_col11, #T_6c799_row8_col0, #T_6c799_row8_col5, #T_6c799_row8_col6, #T_6c799_row8_col7, #T_6c799_row8_col8, #T_6c799_row8_col9, #T_6c799_row8_col10, #T_6c799_row8_col11, #T_6c799_row9_col0, #T_6c799_row9_col5, #T_6c799_row9_col6, #T_6c799_row9_col7, #T_6c799_row9_col8, #T_6c799_row9_col9, #T_6c799_row9_col10, #T_6c799_row9_col11, #T_6c799_row10_col0, #T_6c799_row10_col5, #T_6c799_row10_col6, #T_6c799_row10_col7, #T_6c799_row10_col8, #T_6c799_row10_col9, #T_6c799_row10_col10, #T_6c799_row10_col11 {
#   background-color: gray;
# }
# </style>
# <table id="T_6c799">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6c799_level0_col0" class="col_heading level0 col0" >work_dedication</th>
#       <th id="T_6c799_level0_col1" class="col_heading level0 col1" >monthly_gross_salary</th>
#       <th id="T_6c799_level0_col2" class="col_heading level0 col2" >monthly_net_salary</th>
#       <th id="T_6c799_level0_col3" class="col_heading level0 col3" >salary_comparison_last_semester</th>
#       <th id="T_6c799_level0_col4" class="col_heading level0 col4" >profile_years_experience</th>
#       <th id="T_6c799_level0_col5" class="col_heading level0 col5" >tools_platform</th>
#       <th id="T_6c799_level0_col6" class="col_heading level0 col6" >tools_programming_languages</th>
#       <th id="T_6c799_level0_col7" class="col_heading level0 col7" >tools_frameworks</th>
#       <th id="T_6c799_level0_col8" class="col_heading level0 col8" >tools_data_bases</th>
#       <th id="T_6c799_level0_col9" class="col_heading level0 col9" >tools_qa_testing</th>
#       <th id="T_6c799_level0_col10" class="col_heading level0 col10" >profile_level_study</th>
#       <th id="T_6c799_level0_col11" class="col_heading level0 col11" >profile_gender</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6c799_level0_row0" class="row_heading level0 row0" >count</th>
#       <td id="T_6c799_row0_col0" class="data row0 col0" >5358</td>
#       <td id="T_6c799_row0_col1" class="data row0 col1" >$5,358.00</td>
#       <td id="T_6c799_row0_col2" class="data row0 col2" >$5,358.00</td>
#       <td id="T_6c799_row0_col3" class="data row0 col3" >5358.00</td>
#       <td id="T_6c799_row0_col4" class="data row0 col4" >5358.00</td>
#       <td id="T_6c799_row0_col5" class="data row0 col5" >5357</td>
#       <td id="T_6c799_row0_col6" class="data row0 col6" >5356</td>
#       <td id="T_6c799_row0_col7" class="data row0 col7" >5356</td>
#       <td id="T_6c799_row0_col8" class="data row0 col8" >5355</td>
#       <td id="T_6c799_row0_col9" class="data row0 col9" >5354</td>
#       <td id="T_6c799_row0_col10" class="data row0 col10" >2659</td>
#       <td id="T_6c799_row0_col11" class="data row0 col11" >5358</td>
#     </tr>
#     <tr>
#       <th id="T_6c799_level0_row1" class="row_heading level0 row1" >unique</th>
#       <td id="T_6c799_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_6c799_row1_col1" class="data row1 col1" >missing</td>
#       <td id="T_6c799_row1_col2" class="data row1 col2" >missing</td>
#       <td id="T_6c799_row1_col3" class="data row1 col3" >missing</td>
#       <td id="T_6c799_row1_col4" class="data row1 col4" >missing</td>
#       <td id="T_6c799_row1_col5" class="data row1 col5" >1197</td>
#       <td id="T_6c799_row1_col6" class="data row1 col6" >1318</td>
#       <td id="T_6c799_row1_col7" class="data row1 col7" >1128</td>
#       <td id="T_6c799_row1_col8" class="data row1 col8" >1095</td>
#       <td id="T_6c799_row1_col9" class="data row1 col9" >538</td>
#       <td id="T_6c799_row1_col10" class="data row1 col10" >7</td>
#       <td id="T_6c799_row1_col11" class="data row1 col11" >14</td>
#     </tr>
#     <tr>
#       <th id="T_6c799_level0_row2" class="row_heading level0 row2" >top</th>
#       <td id="T_6c799_row2_col0" class="data row2 col0" >Full-Time</td>
#       <td id="T_6c799_row2_col1" class="data row2 col1" >missing</td>
#       <td id="T_6c799_row2_col2" class="data row2 col2" >missing</td>
#       <td id="T_6c799_row2_col3" class="data row2 col3" >missing</td>
#       <td id="T_6c799_row2_col4" class="data row2 col4" >missing</td>
#       <td id="T_6c799_row2_col5" class="data row2 col5" >Ninguna de las anteriores</td>
#       <td id="T_6c799_row2_col6" class="data row2 col6" >Ninguno de los anteriores</td>
#       <td id="T_6c799_row2_col7" class="data row2 col7" >Ninguno de los anteriores</td>
#       <td id="T_6c799_row2_col8" class="data row2 col8" >Ninguna de las anteriores</td>
#       <td id="T_6c799_row2_col9" class="data row2 col9" >Ninguna de las anteriores</td>
#       <td id="T_6c799_row2_col10" class="data row2 col10" >Universitario</td>
#       <td id="T_6c799_row2_col11" class="data row2 col11" >Varón Cis</td>
#     </tr>
#     <tr>
#       <th id="T_6c799_level0_row3" class="row_heading level0 row3" >freq</th>
#       <td id="T_6c799_row3_col0" class="data row3 col0" >5106</td>
#       <td id="T_6c799_row3_col1" class="data row3 col1" >missing</td>
#       <td id="T_6c799_row3_col2" class="data row3 col2" >missing</td>
#       <td id="T_6c799_row3_col3" class="data row3 col3" >missing</td>
#       <td id="T_6c799_row3_col4" class="data row3 col4" >missing</td>
#       <td id="T_6c799_row3_col5" class="data row3 col5" >1014</td>
#       <td id="T_6c799_row3_col6" class="data row3 col6" >886</td>
#       <td id="T_6c799_row3_col7" class="data row3 col7" >1987</td>
#       <td id="T_6c799_row3_col8" class="data row3 col8" >1299</td>
#       <td id="T_6c799_row3_col9" class="data row3 col9" >3101</td>
#       <td id="T_6c799_row3_col10" class="data row3 col10" >1811</td>
#       <td id="T_6c799_row3_col11" class="data row3 col11" >3902</td>
#     </tr>
#     <tr>
#       <th id="T_6c799_level0_row4" class="row_heading level0 row4" >mean</th>
#       <td id="T_6c799_row4_col0" class="data row4 col0" >missing</td>
#       <td id="T_6c799_row4_col1" class="data row4 col1" >$363,510.54</td>
#       <td id="T_6c799_row4_col2" class="data row4 col2" >$277,010.79</td>
#       <td id="T_6c799_row4_col3" class="data row4 col3" >2.64</td>
#       <td id="T_6c799_row4_col4" class="data row4 col4" >7.34</td>
#       <td id="T_6c799_row4_col5" class="data row4 col5" >missing</td>
#       <td id="T_6c799_row4_col6" class="data row4 col6" >missing</td>
#       <td id="T_6c799_row4_col7" class="data row4 col7" >missing</td>
#       <td id="T_6c799_row4_col8" class="data row4 col8" >missing</td>
#       <td id="T_6c799_row4_col9" class="data row4 col9" >missing</td>
#       <td id="T_6c799_row4_col10" class="data row4 col10" >missing</td>
#       <td id="T_6c799_row4_col11" class="data row4 col11" >missing</td>
#     </tr>
#     <tr>
#       <th id="T_6c799_level0_row5" class="row_heading level0 row5" >std</th>
#       <td id="T_6c799_row5_col0" class="data row5 col0" >missing</td>
#       <td id="T_6c799_row5_col1" class="data row5 col1" >$543,925.46</td>
#       <td id="T_6c799_row5_col2" class="data row5 col2" >$401,942.30</td>
#       <td id="T_6c799_row5_col3" class="data row5 col3" >0.88</td>
#       <td id="T_6c799_row5_col4" class="data row5 col4" >7.20</td>
#       <td id="T_6c799_row5_col5" class="data row5 col5" >missing</td>
#       <td id="T_6c799_row5_col6" class="data row5 col6" >missing</td>
#       <td

# %% [markdown]
# ### Formateo de datos
#
# Se exploran, determinan los tipos adecuados de datos para cada columna de interés y se los formatea si fuera necesario:

# %%
df.dtypes
# Out:
# work_dedication                     object
# monthly_gross_salary               float64
# monthly_net_salary                 float64
# salary_comparison_last_semester      int64
# profile_years_experience           float64
# tools_platform                      object
# tools_programming_languages         object
# tools_frameworks                    object
# tools_data_bases                    object
# tools_qa_testing                    object
# profile_level_study                 object
# profile_gender                      object
# dtype: object

# %% [markdown]
# #### profile_years_experience

# %%
df.profile_years_experience.head(10)
# Out:
# 0   10.00000
# 1    2.00000
# 2    2.00000
# 3    1.00000
# 4    1.00000
# 5    6.00000
# 6    1.00000
# 7    3.00000
# 8    0.00000
# 9    0.00000
# Name: profile_years_experience, dtype: float64

# %% [markdown]
# Se agrupan y clasifican los valores para cantidad de años de experiencia en las categorías: '0-1', '1-2', '3-5', '6-10', '10+',
# transformandola así en **categórica ordenada**.

# %%
def years_of_exp_range(years) -> str:
    """
    given the number of experience, return the corresponding range:
    '0-1', '1-2', '3-5', '6-10', '10+'
    if the number if out of range or is not a number,
    return a numpy nan object
    """
    try:
        if years >= 0 and years < 1:
            return '0-1'
        if years >= 1 and years <= 2:
            return '1-2'
        if years >= 3 and years <= 5:
            return '3-5'
        if years >= 6 and years <= 10:
            return '6-10'
        if years >= 10:
            return '10+'
        else:
            return np.nan
    except TypeError:
        return np.nan

# %%
df['profile_experience_range'] = df.profile_years_experience.apply(years_of_exp_range)
columns_of_interest.append('profile_experience_range')

# %%
df[['profile_years_experience', 'profile_experience_range']].head(10)
# Out:
#    profile_years_experience profile_experience_range
# 0                  10.00000                     6-10
# 1                   2.00000                      1-2
# 2                   2.00000                      1-2
# 3                   1.00000                      1-2
# 4                   1.00000                      1-2
# 5                   6.00000                     6-10
# 6                   1.00000                      1-2
# 7                   3.00000                      3-5
# 8                   0.00000                      0-1
# 9                   0.00000                      0-1

# %%
exp_ranges = ['0-1', '1-2', '3-5', '6-10', '10+']
exp_range_cat = CategoricalDtype(categories=exp_ranges, ordered=True)
df.astype(exp_range_cat).profile_experience_range
# Out:
# 0       6-10
# 1        1-2
# 2        1-2
# 3        1-2
# 4        1-2
#         ...
# 5353    6-10
# 5354    6-10
# 5355    6-10
# 5356     10+
# 5357     0-1
# Name: profile_experience_range, Length: 5358, dtype: category
# Categories (5, object): ['0-1' < '1-2' < '3-5' < '6-10' < '10+']

# %% [markdown]
# ##### Histograma categórico años de experiencia por rangos

# %%
sns.catplot(data=df,
            x='profile_experience_range',
            kind='count',
            order=exp_ranges,
            palette=CATEGORICAL_PALETTE,
            edgecolor='black')

ax = plt.gca()

ax.figsize=FIGSIZE
ax.grid(alpha=0.3)

plt.xlabel('Years of experience by range')
plt.tight_layout()

# %% [markdown]
# > Nótese el elevado valor de conteo para personas encuestadas con `+10` años de experiencia, el que, a priori puede inferir en la media hacia valores elevados de salario.

# %% [markdown]
# #### salary_comparison_last_semester

# %% [markdown]
# #### work_dedication

# %% [markdown]
# Se categoriza la columna `work_dedication` como sigue:

# %%
df.work_dedication.unique()
# Out:
# array(['Full-Time', 'Part-Time'], dtype=object)

# %%
dedication_cat = CategoricalDtype(
    categories=['part-time', 'full-time'], ordered=True
)
df.work_dedication = df.work_dedication.apply(lambda x: x.lower()).astype(dedication_cat)

# %%
df.work_dedication
# Out:
# 0       full-time
# 1       full-time
# 2       full-time
# 3       full-time
# 4       full-time
#           ...
# 5353    full-time
# 5354    full-time
# 5355    full-time
# 5356    full-time
# 5357    part-time
# Name: work_dedication, Length: 5358, dtype: category
# Categories (2, object): ['part-time' < 'full-time']

# %%
df.groupby(['work_dedication'])['monthly_gross_salary'].describe().style.format(
    {col: lambda x: human_format(x) for col in ['mean', 'std', 'min', '25%', '50%', '75%', 'max']},
    precision=2,
)
# Out:
# <style type="text/css">
# </style>
# <table id="T_28771">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_28771_level0_col0" class="col_heading level0 col0" >count</th>
#       <th id="T_28771_level0_col1" class="col_heading level0 col1" >mean</th>
#       <th id="T_28771_level0_col2" class="col_heading level0 col2" >std</th>
#       <th id="T_28771_level0_col3" class="col_heading level0 col3" >min</th>
#       <th id="T_28771_level0_col4" class="col_heading level0 col4" >25%</th>
#       <th id="T_28771_level0_col5" class="col_heading level0 col5" >50%</th>
#       <th id="T_28771_level0_col6" class="col_heading level0 col6" >75%</th>
#       <th id="T_28771_level0_col7" class="col_heading level0 col7" >max</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >work_dedication</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_28771_level0_row0" class="row_heading level0 row0" >part-time</th>
#       <td id="T_28771_row0_col0" class="data row0 col0" >252.00</td>
#       <td id="T_28771_row0_col1" class="data row0 col1" >143K</td>
#       <td id="T_28771_row0_col2" class="data row0 col2" >161K</td>
#       <td id="T_28771_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_28771_row0_col4" class="data row0 col4" >60K</td>
#       <td id="T_28771_row0_col5" class="data row0 col5" >100K</td>
#       <td id="T_28771_row0_col6" class="data row0 col6" >161K</td>
#       <td id="T_28771_row0_col7" class="data row0 col7" >1M</td>
#     </tr>
#     <tr>
#       <th id="T_28771_level0_row1" class="row_heading level0 row1" >full-time</th>
#       <td id="T_28771_row1_col0" class="data row1 col0" >5106.00</td>
#       <td id="T_28771_row1_col1" class="data row1 col1" >374K</td>
#       <td id="T_28771_row1_col2" class="data row1 col2" >554K</td>
#       <td id="T_28771_row1_col3" class="data row1 col3" >0</td>
#       <td id="T_28771_row1_col4" class="data row1 col4" >160K</td>
#       <td id="T_28771_row1_col5" class="data row1 col5" >265K</td>
#       <td id="T_28771_row1_col6" class="data row1 col6" >427K</td>
#       <td id="T_28771_row1_col7" class="data row1 col7" >28M</td>
#     </tr>
#   </tbody>
# </table>

# %%
df.groupby('work_dedication').get_group('part-time').size, df.groupby('work_dedication').get_group('full-time').size
# Out:
# (3276, 66378)

# %% [markdown]
# ##### Histograma part-time vs full-time

# %%
f, ax = plt.subplots(2, 1, figsize=VSUBPLOTS_FIGSIZE, dpi=DPI, sharex=True)
n_bins = 50, 1000

for i, dedication in enumerate(['part-time', 'full-time']):
    df_to_plot = df[df.work_dedication == dedication].monthly_gross_salary
    sns.histplot(df_to_plot, 
                 bins=n_bins[i],
                 label=dedication,
                 color=next(MAIN_PALETTE),
                edgecolor='black',
                 ax=ax[i],)
    
    statistics = df_to_plot.describe(include='all')

    for j, name in enumerate(['mean', 'std']):
        statistic = statistics[name]
        ax[i].axvline(statistic,
                      label=f'{name}: {human_format(statistic)}',
                      color=CATEGORICAL_PALETTE.as_hex()[-j],
                      linestyle='dashed')
        
    for j, st in enumerate(['25%', '50%', '75%']):
        statistic = statistics[st]
        ax[i].axvline(statistic,
                      label=f'{st}: {human_format(statistic)}',
                      color=SECUENTIAL_PALETTE.as_hex()[j],
                      linestyle='dashed')
        
    ax[i].xaxis.set_major_formatter(FORMATTER)
    ax[i].grid(alpha=0.3)
    ax[i].legend()

plt.xlim(0, 3 * statistics['std'])
plt.xlabel('salary in ARS')
plt.tight_layout()

# %% [markdown]
# En base al histograma anterior, los diferentes valores de conteo y en particular de estadísticos, así como la imposibilidad de relacionar certeramente las horas de dedicación entre part-time *(podrían ser 4 horas diarias, algunas horas a la semana, unas pocas al mes, etc)* se resuelve analizar en dos diferentes datasets, las dos diferentes categorías correspondientes a `work_dedication` ('part-time' y 'full-time')

# %% [markdown]
# #### tools

# %% [markdown]
# Se transforman a `list` las columnas que contienen enumeraciones de lenguajes/plataformas/tecnologías para hacer el conteo de las mismas:

# %%
df.tools_programming_languages
# Out:
# 0                                             Python
# 1       CSS, HTML, Java, Javascript, SQL, TypeScript
# 2                            Javascript, PHP, Python
# 3                             Javascript, TypeScript
# 4                              CSS, HTML, Javascript
#                             ...
# 5353                       Ninguno de los anteriores
# 5354                       Ninguno de los anteriores
# 5355                                       HTML, SQL
# 5356                                 Javascript, SQL
# 5357                       Ninguno de los anteriores
# Name: tools_programming_languages, Length: 5358, dtype: object

# %%
for col in ['tools_platform', 'tools_programming_languages', 'tools_frameworks', 'tools_data_bases', 'tools_qa_testing']:
    df[f'list_of_{col}'] = df[col].apply(
        lambda x: [
            entry.lower() for entry in str(x).split(', ') if 'Ningun' not in entry
        ] or np.nan)

# %%
columns_of_interest = [f'list_of_{col}' if 'tool' in col else col for col in columns_of_interest]
df = df[columns_of_interest]

df.head()
# Out:
#   work_dedication  monthly_gross_salary  monthly_net_salary
# 0       full-time          300000.00000        245000.00000  \
# 1       full-time          900000.00000        850000.00000
# 2       full-time          120000.00000        115000.00000
# 3       full-time          440000.00000             0.00000
# 4       full-time          140000.00000        125000.00000
#
#    salary_comparison_last_semester  profile_years_experience
# 0                                2                  10.00000  \
# 1                                4                   2.00000
# 2                                2                   2.00000
# 3                                3                   1.00000
# 4                                2                   1.00000
#
#                  list_of_tools_platform
# 0  [amazon web services, linux, vmware]  \
# 1                 [amazon web services]
# 2                 [amazon web services]
# 3                [firebase, serverless]
# 4                 [amazon web services]
#
#               list_of_tools_programming_languages  list_of_tools_frameworks
# 0                                        [python]                       NaN  \
# 1  [css, html, java, javascript, sql, typescript]                [react.js]
# 2                       [javascript, php, python]  [flask, laravel, vue.js]
# 3                        [javascript, typescript]       [node.js, react.js]
# 4                         [css, html, javascript]                [react.js]
#
#    list_of_tools_data_bases           list_of_tools_qa_testing
# 0           [elasticsearch]  [postman, visual studio coded ui]  \
# 1              [postgresql]                          [cypress]
# 2                 [mariadb]                                NaN
# 3  [elasticsearch, mongodb]                                NaN
# 4                   [mysql]                                NaN
#
#   profile_level_study profile_gender profile_experience_range
# 0       Universitario      Varón Cis                     6-10
# 1                 NaN      Varón Cis                      1-2
# 2                 NaN      Varón Cis                      1-2
# 3                 NaN      Varón Cis                      1-2
# 4                 NaN      Varón Cis                      1-2

# %% [markdown]
# ### Filtrado de filas para lenguajes de programación (ejercicio 2, item 2)

# %% [markdown]
# Se "dropean" aquellas filas del DataFrame que al cabo del formateo de las columnas de interés, resulten en `NaN` en la columna `list_of_tools_programming_languages`, dado que es la columna protagonista junto con las de salarios.

# %%
df[df.list_of_tools_programming_languages.isna()]
# Out:
#      work_dedication  monthly_gross_salary  monthly_net_salary
# 10         full-time          242000.00000        202029.00000  \
# 11         full-time          280000.00000        180000.00000
# 23         full-time          212765.96000        172601.00000
# 43         full-time          122000.00000        106000.00000
# 47         full-time          275000.00000        253000.00000
# ...              ...                   ...                 ...
# 5345       full-time          314000.00000           230.00000
# 5349       full-time             800.00000             0.00000
# 5353       full-time             311.70000           214.80000
# 5354       full-time          150000.00000         93000.00000
# 5357       part-time           60000.00000         45000.00000
#
#       salary_comparison_last_semester  profile_years_experience
# 10                                  3                   3.00000  \
# 11                                  1                  25.00000
# 23                                  2                   0.00000
# 43                                  2                   4.00000
# 47                                  3                   5.00000
# ...                               ...                       ...
# 5345                                2                   3.00000
# 5349                                4                   6.00000
# 5353                                2                   6.00000
# 5354                                2                   7.00000
# 5357                                2                   0.00000
#
#                                  list_of_tools_platform
# 10                                              [linux]  \
# 11                                                  NaN
# 23                       [azure, linux, windows server]
# 43                                                  NaN
# 47                                             [vmware]
# ...                                                 ...
# 5345  [amazon web services, docker, kubernetes, linu...
# 5349                                                NaN
# 5353                                            [azure]
# 5354                                                NaN
# 5357                         [office 365, jira, zephyr]
#
#      list_of_tools_programming_languages list_of_tools_frameworks
# 10                                   NaN                      NaN  \
# 11                                   NaN                      NaN
# 23                                   NaN                      NaN
# 43                                   NaN                      NaN
# 47                                   NaN                      NaN
# ...                                  ...                      ...
# 5345                                 NaN                      NaN
# 5349                                 NaN              [wordpress]
# 5353                                 NaN                      NaN
# 5354                                 NaN                      NaN
# 5357                                 NaN              [wordpress]
#
#      list_of_tools_data_bases list_of_tools_qa_testing profile_level_study
# 10                        NaN                [postman]       Universitario  \
# 11                        NaN                      NaN       Universitario
# 23     [microsoft sql server]                      NaN          Secundario
# 43                        NaN                      NaN                 NaN
# 47           [oracle, sqlite]                      NaN                 NaN
# ...                       ...                      ...                 ...
# 5345                      NaN                      NaN                 NaN
# 5349                      NaN                [postman]                 NaN
# 5353                      NaN                      NaN                 NaN
# 5354                  [mysql]                      NaN                 NaN
# 5357                      NaN                      NaN       Universitario
#
#      profile_gender profile_experience_range
# 10        Varón Cis                      3-5
# 11        Varón Cis                      10+
# 23        Varón Cis                      0-1
# 43        Varón cis                      3-5
# 47        Mujer Cis                      3-5
# ...             ...                      ...
# 5345      Varón Cis                      3-5
# 5349      Mujer Cis                     6-10
# 5353      Mujer Cis                     6-10
# 5354      Mujer Cis                     6-10
# 5357       Bigénero                      0-1
#
# [886 rows x 13 columns]

# %%
df_without_nan_programming_languages = df.dropna(subset=['list_of_tools_programming_languages'])

# %%
df.size, df_without_nan_programming_languages.size
# Out:
# (69654, 58136)

# %%
df = df_without_nan_programming_languages

# %%
df.head()
# Out:
#   work_dedication  monthly_gross_salary  monthly_net_salary
# 0       full-time          300000.00000        245000.00000  \
# 1       full-time          900000.00000        850000.00000
# 2       full-time          120000.00000        115000.00000
# 3       full-time          440000.00000             0.00000
# 4       full-time          140000.00000        125000.00000
#
#    salary_comparison_last_semester  profile_years_experience
# 0                                2                  10.00000  \
# 1                                4                   2.00000
# 2                                2                   2.00000
# 3                                3                   1.00000
# 4                                2                   1.00000
#
#                  list_of_tools_platform
# 0  [amazon web services, linux, vmware]  \
# 1                 [amazon web services]
# 2                 [amazon web services]
# 3                [firebase, serverless]
# 4                 [amazon web services]
#
#               list_of_tools_programming_languages  list_of_tools_frameworks
# 0                                        [python]                       NaN  \
# 1  [css, html, java, javascript, sql, typescript]                [react.js]
# 2                       [javascript, php, python]  [flask, laravel, vue.js]
# 3                        [javascript, typescript]       [node.js, react.js]
# 4                         [css, html, javascript]                [react.js]
#
#    list_of_tools_data_bases           list_of_tools_qa_testing
# 0           [elasticsearch]  [postman, visual studio coded ui]  \
# 1              [postgresql]                          [cypress]
# 2                 [mariadb]                                NaN
# 3  [elasticsearch, mongodb]                                NaN
# 4                   [mysql]                                NaN
#
#   profile_level_study profile_gender profile_experience_range
# 0       Universitario      Varón Cis                     6-10
# 1                 NaN      Varón Cis                      1-2
# 2                 NaN      Varón Cis                      1-2
# 3                 NaN      Varón Cis                      1-2
# 4                 NaN      Varón Cis                      1-2

# %% [markdown]
# ##### programming languages
#
# Por ser una de las columnas protagonistas del análisis, se realiza un tratamiento extra, que consiste en corroborar que los strings listados corresponden o se encuentran incluidos en el nombre de un lenguaje de programación válido.
#
# Se extraen todos los ítems de la [lista de lenguajes de programación de wikipedia](https://en.wikipedia.org/wiki/List_of_programming_languages):

# %%
wiki_programming_languages = [
    "A.NET (A#/A sharp)", "A-0 System", "A+ (A plus)", "ABAP", "ABC", "ABC ALGOL", "ACC", "Accent (Rational Synergy)", "Ace Distributed Application Specification Language (DASL)",
    "Action!", "ActionScript", "Actor", "Ada – ISO/IEC 8652", "Adenine (Haystack)", "AdvPL", "Agda", "Agilent VEE (Keysight VEE)", "Agora", "AIMMS", "Aldor", "Alef", "ALF", "ALGOL 58",
    "ALGOL 60", "ALGOL 68", "ALGOL W", "Alice (Alice ML)", "Alma-0", "AmbientTalk", "Amiga E", "AMPL", "Analitik", "AngelScript", "Apache Pig latin", "Apex (Salesforce.com, Inc)", "APL",
    "App Inventor for Android's visual block language (MIT App Inventor)", "AppleScript", "APT", "Arc", "ARexx", "Argus", "Assembly language (ASM)", "AutoHotkey", "AutoIt",
    "AutoLISP / Visual LISP", "Averest", "AWK", "Axum", "B", "Babbage", "Ballerina", "Bash/Shell", "BASIC", "Batch file (Windows/MS-DOS)", "bc (basic calculator)", "BCPL", "BeanShell",
    "BETA", "BLISS", "Blockly", "BlooP", "Boo", "Boomerang", "Bosque", "C – ISO/IEC 9899", "C-- (C minus minus)", "C++ (C plus plus) – ISO/IEC 14882", "C*", "C# (C sharp) – ISO/IEC 23270",
    "C/AL", "Caché ObjectScript", "C Shell (csh)", "Caml", "Carbon", "Catrobat", "Cayenne (Lennart Augustsson)", "CDuce", "Cecil", "CESIL (Computer Education in Schools Instruction Language)",
    "Céu", "Ceylon", "CFEngine", "Cg (High-Level Shader/Shading Language [HLSL])", "Ch", "Chapel (Cascade High Productivity Language)", "Charm", "CHILL", "CHIP-8", "ChucK",
    "Cilk (also Cilk++ and Cilk plus)", "Claire", "Clarion", "Clean", "Clipper", "CLIPS", "CLIST", "Clojure", "CLU", "CMS-2", "COBOL – ISO/IEC 1989", "CobolScript – COBOL Scripting language",
    "Cobra", "CoffeeScript", "ColdFusion", "COMAL", "COMIT", "Common Intermediate Language (CIL)", "Common Lisp (also known as CL)", "COMPASS", "Component Pascal", "COMTRAN", "Concurrent Pascal",
    "Constraint Handling Rules (CHR)", "Control Language", "Coq", "Coral 66", "CorVision", "COWSEL", "CPL", "Cryptol", "Crystal", "Csound", "Cuneiform", "Curl", "Curry", "Cybil", "Cyclone",
    "Cypher Query Language", "Cython", "CEEMAC", "D (also known as dlang)", "Dart", "Darwin", "DataFlex", "Datalog", "DATATRIEVE", "dBase", "dc", "DCL (DIGITAL Command Language)", "Delphi",
    "DIBOL", "DinkC", "Dog", "Draco", "DRAKON", "Dylan", "DYNAMO", "DAX (Data Analysis Expressions)", "E", "Ease", "Easy PL/I", "EASYTRIEVE PLUS", "eC", "ECMAScript", "Edinburgh IMP", "EGL",
    "Eiffel", "ELAN", "Elixir", "Elm", "Emacs Lisp", "Emerald", "Epigram", "EPL (Easy Programming Language)", "Erlang", "es", "Escher", "ESPOL", "Esterel", "Etoys", "Euclid", "Euler", "Euphoria",
    "EusLisp Robot Programming Language", "CMS EXEC (EXEC)", "EXEC 2", "Executable UML", "Ezhil", "F", "F# (F sharp)", "F*", "Factor", "Fantom", "FAUST", "FFP", "fish", "Fjölnir", "FL", "Flavors",
    "Flex", "Flix", "FlooP", "FLOW-MATIC (B0)", "FOCAL (Formulating On-Line Calculations in Algebraic Language/FOrmula CALculator)", "FOCUS", "FOIL", "FORMAC (FORMula MAnipulation Compiler)",
    "@Formula", "Forth", "Fortran – ISO/IEC 1539", "Fortress", "FP", "FoxBase/FoxPro", "Franz Lisp", "Futhark", "F-Script", "Game Maker Language", "GameMonkey Script",
    "GAMS (General Algebraic Modeling System)", "GAP", "G-code", "GDScript (Godot)", "Genie", "GDL (Geometric Description Language)", "GEORGE", "GLSL (OpenGL Shading Language)", "GNU E",
    "GNU Guile (GNU Ubiquitous Intelligent Language for Extensions)", "Go", "Go!", "GOAL (Game Oriented Assembly Lisp)", "Gödel", "Golo", "GOM (Good Old Mad)", "Google Apps Script", "Gosu",
    "GOTRAN (IBM 1620)", "GPSS (General Purpose Simulation System)", "GraphTalk (Computer Sciences Corporation)", "GRASS", "Grasshopper", "Groovy (Apache Groovy)", "Hack", "HAGGIS", "HAL/S",
    "Halide (programming language)", "Hamilton C shell", "Harbour", "Hartmann pipelines", "Haskell", "Haxe", "Hermes", "High Level Assembly (HLA)", "High Level Shader Language (HLSL)", "Hollywood",
    "HolyC (TempleOS)", "Hop", "Hopscotch", "Hope", "Hume", "HyperTalk", "Hy", "Io", "Icon", "IBM Basic assembly language", "IBM HAScript", "IBM Informix-4GL", "IBM RPG", "IDL", "Idris", "Inform",
    "ISLISP", "J", "J# (J sharp)", "J++ (J plus plus)", "JADE", "Jai", "JAL", "Janus (concurrent constraint programming language)", "Janus (time-reversible computing programming language)", "JASS",
    "Java", "JavaFX Script", "JavaScript", "Jess", "JCL", "JEAN", "Join Java", "JOSS", "Joule", "JOVIAL", "Joy", "jq", "JScript", "JScript .NET", "Julia", "Jython", "K", "Kaleidoscope", "Karel",
    "KEE", "Kixtart", "Klerer-May System", "KIF (Knowledge Interchange Format)", "Kojo", "Kotlin", "KRC", "KRL", "KRL (KUKA Robot Language)", "KRYPTON", "KornShell (ksh)", "Kodu", "Kv (Kivy)",
    "LabVIEW", "Ladder", "LANSA", "Lasso", "Lava", "LC-3", "Lean", "Legoscript", "LIL", "LilyPond", "Limbo", "LINC", "Lingo", "LINQ", "LIS", "LISA", "Language H", "Lisp – ISO/IEC 13816", "Lite-C",
    "Lithe", "Little b", "LLL", "Logo", "Logtalk", "LotusScript", "LPC", "LSE", "LSL", "LiveCode", "LiveScript", "Lua", "Lucid", "Lustre", "LYaPAS", "Lynx", "M Formula language", "M2001", "M4", "M#",
    "Machine code", "MAD (Michigan Algorithm Decoder)", "MAD/I", "Magik", "Magma", "Máni", "Maple", "MAPPER (now part of BIS)", "MARK-IV (now VISION:BUILDER)", "Mary", "MATLAB",
    "MASM Microsoft Assembly x86", "MATH-MATIC", "Maude system", "Maxima (see also Macsyma)", "Max (Max Msp – Graphical Programming Environment)", "MaxScript internal language 3D Studio Max",
    "Maya (MEL)", "MDL", "Mercury", "Mesa", "MHEG-5 (Interactive TV programming language)", "Microcode", "Microsoft Power Fx", "MIIS", "Milk (programming language)", "MIMIC", "Mirah", "Miranda",
    "MIVA Script", "ML", "Model 204", "Modelica", "Malbolge", "Modula", "Modula-2", "Modula-3", "Mohol", "Mojo", "MOO", "Mortran", "Mouse", "MPD", "MSL", "MUMPS", "MuPAD", "Mutan",
    "Mystic Programming Language (MPL)", "NASM", "Napier88", "Neko", "Nemerle", "NESL", "Net.Data", "NetLogo", "NetRexx", "NewLISP", "NEWP", "Newspeak", "NewtonScript", "Nial", "Nickle (NITIN)",
    "Nim", "Nix (Systems configuration language)", "NPL", "Not eXactly C (NXC)", "Not Quite C (NQC)", "NSIS", "Nu", "NWScript", "NXT-G", "o:XML", "Oak", "Oberon", "OBJ2", "Object Lisp", "ObjectLOGO",
    "Object REXX", "Object Pascal", "Objective-C", "Obliq", "OCaml", "occam", "occam-π", "Octave", "OmniMark", "Opa", "Opal", "Open Programming Language (OPL)", "OpenCL",
    "OpenEdge Advanced Business Language (ABL)", "OpenVera", "OpenQASM", "OPS5", "OptimJ", "Orc", "ORCA/Modula-2", "Oriel", "Orwell", "Oxygene", "Oz", "P", "P4", "P′′", "ParaSail", "PARI/GP",
    "Pascal – ISO 7185", "Pascal Script", "PCASTL", "PCF", "PEARL", "PeopleCode", "Perl", "PDL", "Pharo", "PHP", "Pico", "Picolisp", "Pict", "Pike", "PILOT", "Pipelines", "Pizza", "PL-11", "PL/0",
    "PL/B", "PL/C", "PL/I – ISO 6160", "PL/M", "PL/P", "PL/S", "PL/SQL", "PL360", "PLANC", "Plankalkül", "Planner", "PLEX", "PLEXIL", "Plus", "POP-11", "POP-2", "PostScript", "PortablE",
    "POV-Ray SDL", "Powerhouse", "PowerBuilder – 4GL GUI application generator from Sybase", "PowerShell", "PPL", "Processing", "Processing.js", "Prograph", "Project Verona", "Prolog", "PROMAL",
    "Promela", "PROSE modeling language", "PROTEL", "ProvideX", "Pro*C", "Pure", "Pure Data", "PureScript", "PWCT", "Python", "Q (programming language from Kx Systems)", "Q#", "Qalb",
    "Quantum Computation Language", "QtScript", "QuakeC", "QPL", ".QL", "R", "R++", "Racket", "Raku", "RAPID", "Rapira", "Ratfiv", "Ratfor", "rc", "Reason", "REBOL", "Red", "Redcode", "REFAL",
    "REXX", "Ring", "ROOP", "RPG", "RPL", "RSL", "RTL/2", "Ruby", "Rust", "S", "S2", "S3", "S-Lang", "S-PLUS", "SA-C", "SabreTalk", "SAIL", "SAKO", "SAS", "SASL", "Sather", "Sawzall", "Scala",
    "Scheme", "Scilab", "Scratch", "ScratchJr", "Script.NET", "Sed", "Seed7", "Self", "SenseTalk", "SequenceL", "Serpent", "SETL", "Short Code", "SIMPOL", "SIGNAL", "SiMPLE", "SIMSCRIPT", "Simula",
    "Simulink", "SISAL", "SKILL", "SLIP", "SMALL", "Smalltalk", "SML", "Strongtalk", "Snap!", "SNOBOL (SPITBOL)", "Snowball", "SOL", "Solidity", "SOPHAEROS", "Source", "SPARK", "Speakeasy",
    "Speedcode", "SPIN", "SP/k", "SPS", "SQL", "SQR", "Squeak", "Squirrel", "SR", "S/SL", "Starlogo", "Strand", "Stata", "Stateflow", "Subtext", "SBL", "SuperCollider", "Superplan", "SuperTalk",
    "Swift (Apple programming language)", "Swift (parallel scripting language)", "SYMPL", "T", "TACL", "TACPOL", "TADS (Text Adventure Development System)", "TAL", "Tcl", "Tea",
    "TECO (Text Editor and Corrector)", "TELCOMP", "TeX", "TEX (Text Executive Programming Language)", "TIE", "TMG (TransMoGrifier), compiler-compiler", "Tom", "Toi", "Topspeed (Clarion)",
    "TPU (Text Processing Utility)", "Trac", "TTM", "T-SQL (Transact-SQL)", "Transcript (LiveCode)", "TTCN (Tree and Tabular Combined Notation)", "Turing", "TUTOR (PLATO Author Language)",
    "TXL", "TypeScript", "Tynker", "Ubercode", "UCSD Pascal", "Umple", "Unicon", "Uniface", "UNITY", "UnrealScript", "Vala", "Vim script", "Viper (Ethereum/Ether (ETH))", "Visual DataFlex",
    "Visual DialogScript", "Visual FoxPro", "Visual J++ (Visual J plus plus)", "Visual LISP", "Visual Objects", "Visual Prolog", "WATFIV, WATFOR (WATerloo FORtran IV)", "WebAssembly",
    "WebDNA", "Whiley", "Winbatch", "Wolfram Language", "Wyvern", "X++ (X plus plus/Microsoft Dynamics AX)", "X10", "xBase++ (xBase plus plus)", "XBL", "XC (targets XMOS architecture)",
    "xHarbour", "XL", "Xojo", "XOTcl", "Xod", "XPL", "XPL0", "XQuery", "XSB", "XSharp (X#)", "XSLT", "Xtend", "Yorick", "YQL", "Yoix", "Z notation", "Z shell", "Zebra, ZPL, ZPL2", "Zeno",
    "ZetaLisp", "Zig", "Zonnon", "ZOPL", "ZPL", "Z++"
]

# %% [markdown]
# > This is an index to notable programming languages, in current or historical use. Dialects of BASIC, esoteric programming languages, and markup languages are not included. A programming language does not need to be imperative or Turing-complete, but must be executable and so does not include markups such as HTML or XML, but does include domain-specific languages such as SQL and its dialects.

# %%
WIKI_PROGRAMMING_LANGUAGES = [lang.split('(')[0].split('-')[0].strip().lower() for lang in wiki_programming_languages]   # this could be replaced by a regex
WIKI_PROGRAMMING_LANGUAGES.extend(['html', 'css', 'sql', '.net', 'cobol', 'vba', 'arduino', 'assembler', 'objective-c'])

# %%
df.list_of_tools_programming_languages.apply(lambda v: [x.split('(')[0].split('-')[0].strip().lower() for x in v])  # this could be replaced by a regex
# Out:
# 0                                             [python]
# 1       [css, html, java, javascript, sql, typescript]
# 2                            [javascript, php, python]
# 3                             [javascript, typescript]
# 4                              [css, html, javascript]
#                              ...
# 5350                                      [javascript]
# 5351                                     [python, sql]
# 5352                                             [sql]
# 5355                                       [html, sql]
# 5356                                 [javascript, sql]
# Name: list_of_tools_programming_languages, Length: 4472, dtype: object

# %%
df.list_of_tools_programming_languages.apply(
    lambda v: ['bash/shell' if 'bash' in x or 'shell' in x else x for x in v]
)
# Out:
# 0                                             [python]
# 1       [css, html, java, javascript, sql, typescript]
# 2                            [javascript, php, python]
# 3                             [javascript, typescript]
# 4                              [css, html, javascript]
#                              ...
# 5350                                      [javascript]
# 5351                                     [python, sql]
# 5352                                             [sql]
# 5355                                       [html, sql]
# 5356                                 [javascript, sql]
# Name: list_of_tools_programming_languages, Length: 4472, dtype: object

# %%
df['list_of_normalized_languages'] = df.list_of_tools_programming_languages.apply(
    lambda v: [x for x in v if x in WIKI_PROGRAMMING_LANGUAGES]
)

# %%
df.list_of_normalized_languages.apply(lambda v: np.nan is not v)
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#         ...
# 5350    True
# 5351    True
# 5352    True
# 5355    True
# 5356    True
# Name: list_of_normalized_languages, Length: 4472, dtype: bool

# %%
df[~df.list_of_normalized_languages.isna()].head(15)[['monthly_gross_salary', 'list_of_tools_programming_languages']].style.format(
    {'monthly_gross_salary': human_format,}
)
# Out:
# <style type="text/css">
# </style>
# <table id="T_eedfb">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_eedfb_level0_col0" class="col_heading level0 col0" >monthly_gross_salary</th>
#       <th id="T_eedfb_level0_col1" class="col_heading level0 col1" >list_of_tools_programming_languages</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_eedfb_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_eedfb_row0_col0" class="data row0 col0" >300K</td>
#       <td id="T_eedfb_row0_col1" class="data row0 col1" >['python']</td>
#     </tr>
#     <tr>
#       <th id="T_eedfb_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_eedfb_row1_col0" class="data row1 col0" >900K</td>
#       <td id="T_eedfb_row1_col1" class="data row1 col1" >['css', 'html', 'java', 'javascript', 'sql', 'typescript']</td>
#     </tr>
#     <tr>
#       <th id="T_eedfb_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_eedfb_row2_col0" class="data row2 col0" >120K</td>
#       <td id="T_eedfb_row2_col1" class="data row2 col1" >['javascript', 'php', 'python']</td>
#     </tr>
#     <tr>
#       <th id="T_eedfb_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_eedfb_row3_col0" class="data row3 col0" >440K</td>
#       <td id="T_eedfb_row3_col1" class="data row3 col1" >['javascript', 'typescript']</td>
#     </tr>
#     <tr>
#       <th id="T_eedfb_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_eedfb_row4_col0" class="data row4 col0" >140K</td>
#       <td id="T_eedfb_row4_col1" class="data row4 col1" >['css', 'html', 'javascript']</td>
#     </tr>
#     <tr>
#       <th id="T_eedfb_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_eedfb_row5_col0" class="data row5 col0" >633K</td>
#       <td id="T_eedfb_row5_col1" class="data row5 col1" >['go', 'java']</td>
#     </tr>
#     <tr>
#       <th id="T_eedfb_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_eedfb_row6_col0" class="data row6 col0" >110K</td>
#       <td id="T_eedfb_row6_col1" class="data row6 col1" >['java']</td>
#     </tr>
#     <tr>
#       <th id="T_eedfb_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_eedfb_row7_col0" class="data row7 col0" >157K</td>
#       <td id="T_eedfb_row7_col1" class="data row7 col1" >['html', 'javascript', 'sql', 'typescript']</td>
#     </tr>
#     <tr>
#       <th id="T_eedfb_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_eedfb_row8_col0" class="data row8 col0" >55K</td>
#       <td id="T_eedfb_row8_col1" class="data row8 col1" >['sql']</td>
#     </tr>
#     <tr>
#       <th id="T_eedfb_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_eedfb_row9_col0" class="data row9 col0" >190K</td>
#       <td id="T_eedfb_row9_col1" class="data row9 col1" >['java']</td>
#     </tr>
#     <tr>
#       <th id="T_eedfb_level0_row10" class="row_heading level0 row10" >12</th>
#       <td id="T_eedfb_row10_col0" class="data row10 col0" >330K</td>
#       <td id="T_eedfb_row10_col1" class="data row10 col1" >['.net', 'c#', 'css', 'html', 'javascript', 'sql']</td>
#     </tr>
#     <tr>
#       <th id="T_eedfb_level0_row11" class="row_heading level0 row11" >13</th>
#       <td id="T_eedfb_row11_col0" class="data row11 col0" >625K</td>
#       <td id="T_eedfb_row11_col1" class="data row11 col1" >['bash/shell', 'python', 'sql']</td>
#     </tr>
#     <tr>
#       <th id="T_eedfb_level0_row12" class="row_heading level0 row12" >14</th>
#       <td id="T_eedfb_row12_col0" class="data row12 col0" >222K</td>
#       <td id="T_eedfb_row12_col1" class="data row12 col1" >['groovy', 'java', 'javascript']</td>
#     </tr>
#     <tr>
#       <th id="T_eedfb_level0_row13" class="row_heading level0 row13" >15</th>
#       <td id="T_eedfb_row13_col0" class="data row13 col0" >380K</td>
#       <td id="T_eedfb_row13_col1" class="data row13 col1" >['bash/shell', 'html', 'javascript', 'php', 'python', 'typescript']</td>
#     </tr>
#     <tr>
#       <th id="T_eedfb_level0_row14" class="row_heading level0 row14" >16</th>
#       <td id="T_eedfb_row14_col0" class="data row14 col0" >156K</td>
#       <td id="T_eedfb_row14_col1" class="data row14 col1" >['html', 'javascript', 'php', 'sql']</td>
#     </tr>
#   </tbody>
# </table>

# %%
columns_of_interest.append('list_of_normalized_languages')

# %% [markdown]
# #### salary_comparison_last_semester

# %%
df.salary_comparison_last_semester.unique()
# Out:
# array([2, 4, 3, 1])

# %%
df.salary_comparison_last_semester.describe()
# Out:
# count   4472.00000
# mean       2.66860
# std        0.86443
# min        1.00000
# 25%        2.00000
# 50%        3.00000
# 75%        3.00000
# max        4.00000
# Name: salary_comparison_last_semester, dtype: float64

# %%
df.salary_comparison_last_semester.astype('category')
# Out:
# 0       2
# 1       4
# 2       2
# 3       3
# 4       2
#        ..
# 5350    1
# 5351    2
# 5352    3
# 5355    2
# 5356    3
# Name: salary_comparison_last_semester, Length: 4472, dtype: category
# Categories (4, int64): [1, 2, 3, 4]

# %% [markdown]
# ##### Histograma categórico comparación salario contra el último semestre

# %%
sns.catplot(data=df,
            x='salary_comparison_last_semester',
            kind='count',
            palette=CATEGORICAL_PALETTE,
           edgecolor='black')

# %% [markdown]
# #### profile_gender
#
# La población de respuestas para géneros que no se puedan agrupar en los grupos binarios *mujer* y *varón*, por no estar normalizadas y pertenecer a una población pequeña, se asignan a un mismo grupo:

# %%
df.profile_gender.unique()
# Out:
# array(['Varón Cis', 'Varón cis', 'Mujer Cis', 'Mujer', 'Varón Trans',
#        'Queer', 'No binarie', 'Mujer Trans', 'Mujer cis', 'mujer', 'Gay',
#        'Fluido', 'Bigénero', 'Femenino'], dtype=object)

# %%
to_replace = {
    ('Varón Cis', 'Varón cis') : 'varon cis', 
    ('Mujer Cis', 'Mujer', 'Mujer cis', 'mujer', 'femenino', 'Femenino'): 'mujer cis',
    ('Varón Trans', 'Queer', 'No binarie', 'Gay', 'Fluido', 'Bigénero', 'Mujer Trans'): 'diversidades'}

for k, v in to_replace.items():
    old, new = k, v
    df.profile_gender = df.profile_gender.replace(
        old, new
    )

# %%
df.profile_gender
# Out:
# 0       varon cis
# 1       varon cis
# 2       varon cis
# 3       varon cis
# 4       varon cis
#           ...
# 5350    mujer cis
# 5351    mujer cis
# 5352    mujer cis
# 5355    mujer cis
# 5356    varon cis
# Name: profile_gender, Length: 4472, dtype: object

# %%
df.profile_gender.astype('category')
# Out:
# 0       varon cis
# 1       varon cis
# 2       varon cis
# 3       varon cis
# 4       varon cis
#           ...
# 5350    mujer cis
# 5351    mujer cis
# 5352    mujer cis
# 5355    mujer cis
# 5356    varon cis
# Name: profile_gender, Length: 4472, dtype: category
# Categories (3, object): ['diversidades', 'mujer cis', 'varon cis']

# %%
df.profile_gender.value_counts()
# Out:
# profile_gender
# varon cis       3735
# mujer cis        657
# diversidades      80
# Name: count, dtype: int64

# %% [markdown]
# ##### Histograma categórico por género

# %%
sns.catplot(data=df,
            x='profile_gender',
            kind='count',
            palette=CATEGORICAL_PALETTE,
            edgecolor='black')

ax = plt.gca()

ax.figsize=FIGSIZE
ax.grid(alpha=0.3)

plt.xlabel('Gender')
plt.tight_layout()

# %% [markdown]
# > Se puede observar claramente el **sesgo** del dataset, en el que las mujeres están **sub-representadas** respecto a la población humana. Así mismo y por demás las diversidades.

# %% [markdown]
# #### profile_level_study

# %%
df.profile_level_study
# Out:
# 0       Universitario
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
#             ...
# 5350              NaN
# 5351    Universitario
# 5352              NaN
# 5355              NaN
# 5356    Universitario
# Name: profile_level_study, Length: 4472, dtype: object

# %%
df.profile_level_study.unique()
# Out:
# array(['Universitario', nan, 'Terciario', 'Secundario',
#        'Posgrado/Especialización', 'Maestría', 'Doctorado',
#        'Posdoctorado'], dtype=object)

# %%
study_levels = ['Secundario', 'Terciario', 'Universitario', 'Posgrado/Especialización', 'Maestría', 'Doctorado', 'Posdoctorado']
study_cat = CategoricalDtype(categories=study_levels, ordered=True)
df.profile_level_study.astype('str').astype(study_cat)
# Out:
# 0       Universitario
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
#             ...
# 5350              NaN
# 5351    Universitario
# 5352              NaN
# 5355              NaN
# 5356    Universitario
# Name: profile_level_study, Length: 4472, dtype: category
# Categories (7, object): ['Secundario' < 'Terciario' < 'Universitario' < 'Posgrado/Especialización' < 'Maestría' < 'Doctorado' < 'Posdoctorado']

# %% [markdown]
# ##### Histograma categórico por nivel de estudios

# %%
sns.catplot(data=df,
            y='profile_level_study',
            kind='count',
            order=study_levels,
            palette=CATEGORICAL_PALETTE,
            edgecolor='black')

ax = plt.gca()

ax.figsize=FIGSIZE
ax.grid(alpha=0.3)

plt.ylabel('Profile level study')
plt.tight_layout()

# %% [markdown]
# Se puede observar un elevado número de personas encuestadas con nivel universitario alcanzado, desproporcionado por sobre los otros niveles, se podría presumir una muestra sesgada

# %% [markdown]
# ### Función de distribución de probabilidad

# %% [markdown]
# #### Part-time vs full-time

# %%
df_part_time = df.groupby('work_dedication').get_group('part-time')
df_full_time = df.groupby('work_dedication').get_group('full-time')

# %% [markdown]
# ##### Histograma part-time vs full-time

# %%
f, ax = plt.subplots(2, 1, figsize=VSUBPLOTS_FIGSIZE, dpi=DPI, sharex=True)
n_bins = 50, 1200

for i, df in enumerate([df_part_time, df_full_time]):
    sns.histplot(df,
                 x='monthly_gross_salary',
                 bins=n_bins[i],
                 ax=ax[i],
                 label=df.work_dedication.unique()[0],
                 color=next(MAIN_PALETTE),
                 edgecolor='black',  # this is not working well...
                 kde=True)
    
    statistics = df_to_plot.describe(include='all')

    for j, name in enumerate(['mean', 'std']):
        statistic = statistics[name]
        ax[i].axvline(statistic,
                      label=f'{name}: {human_format(statistic)}',
                      color=CATEGORICAL_PALETTE.as_hex()[-j],
                      linestyle='dashed')
        
    for j, st in enumerate(['25%', '50%', '75%']):
        statistic = statistics[st]
        ax[i].axvline(statistic,
                      label=f'{st}: {human_format(statistic)}',
                      color=SECUENTIAL_PALETTE.as_hex()[j],
                      linestyle='dashed')
        
    ax[i].xaxis.set_major_formatter(FORMATTER)
    ax[i].grid(alpha=0.3)
    ax[i].legend()

plt.xlim(0, 3 * statistics['std'])
plt.xlabel('salary in ARS')
plt.tight_layout()

# %% [markdown]
# - Las envolventes sugieren curvas de comportamiento exponencial **normal o gaussiano**.
# - Dado que ambos conjuntos de datos provienen de la misma fuente, se trata a ambos con referencia en la **función de distribución de probabilidad Normal y Gaussiana**.

# %% [markdown]
# ### Salario bruto vs neto (ejercicio 2, item a)

# %% [markdown]
# Del concepto del bruto vs neto se pre-asume que existe una relación lineal y se espera una varianza constante al analizar estas dos variables en contraposición, dado que:
# $\text{salario_neto} = \text{salario_bruto} - \text{deducciones}$

# %% [markdown]
# #### Plot regresión lineal salario bruto vs neto

# %%
sns.jointplot(x='monthly_gross_salary', y='monthly_net_salary', data=df, kind='reg', ax=ax)

ax = plt.gca()

ax.xaxis.set_major_formatter(FORMATTER)
ax.yaxis.set_major_formatter(FORMATTER)

ax.grid(alpha=0.3)
ax.figure.set_size_inches(FIGSIZE)

plt.xlim(0, 3 * df.monthly_gross_salary.std())
plt.ylim(0, 3 * df.monthly_net_salary.std())
plt.xlabel('Gross salary in ARS')
plt.ylabel('Net salary in ARS')

plt.tight_layout()
# Out:
# /tmp/ipykernel_823753/609629132.py:1: UserWarning: Ignoring `ax`; jointplot is a figure-level function.
#   sns.jointplot(x='monthly_gross_salary', y='monthly_net_salary', data=df, kind='reg', ax=ax)

# %%
sns.lmplot(x='monthly_gross_salary',
           y='monthly_net_salary',
           hue='work_dedication',
           data=df, aspect=FIGSIZE[0] / FIGSIZE[1],)

ax = plt.gca()

ax.xaxis.set_major_formatter(FORMATTER)
ax.yaxis.set_major_formatter(FORMATTER)

ax.grid(alpha=0.3)


plt.xlim(0, 3 * df.monthly_gross_salary.std())
plt.ylim(0, 3 * df.monthly_net_salary.std())

plt.xlabel('Gross salary in ARS')
plt.ylabel('Net salary in ARS')

plt.tight_layout()

# %% [markdown]
# Sin embargo, los valores del dataset para las variables de interés en el gráfico antes expluesto se observa que:
# - Existen filas donde $\text{salario_bruto} < \text{salario_neto}$
# la relación es errónea, no se puede discernir el origen del error ni estimar.

# %%
df_without_wrong_salaries_ratio = df[df.monthly_gross_salary > df.monthly_net_salary]

# %%
sns.jointplot(x='monthly_gross_salary', y='monthly_net_salary', data=df_without_wrong_salaries_ratio, kind='reg', ax=ax)

ax = plt.gca()

ax.xaxis.set_major_formatter(FORMATTER)
ax.yaxis.set_major_formatter(FORMATTER)

ax.grid(alpha=0.3)
ax.figure.set_size_inches(FIGSIZE)

plt.xlim(0, 3 * df.monthly_gross_salary.std())
plt.ylim(0, 3 * df.monthly_net_salary.std())
plt.xlabel('Gross salary in ARS')
plt.ylabel('Net salary in ARS')

plt.tight_layout()
# Out:
# /tmp/ipykernel_823753/4198598697.py:1: UserWarning: Ignoring `ax`; jointplot is a figure-level function.
#   sns.jointplot(x='monthly_gross_salary', y='monthly_net_salary', data=df_without_wrong_salaries_ratio, kind='reg', ax=ax)

# %%
sns.lmplot(x='monthly_gross_salary',
           y='monthly_net_salary',
           hue='work_dedication',
           data=df_without_wrong_salaries_ratio, aspect=FIGSIZE[0] / FIGSIZE[1],)

ax = plt.gca()

ax.xaxis.set_major_formatter(FORMATTER)
ax.yaxis.set_major_formatter(FORMATTER)

ax.grid(alpha=0.3)


plt.xlim(0, 3 * df.monthly_gross_salary.std())
plt.ylim(0, 3 * df.monthly_net_salary.std())

plt.xlabel('Gross salary in ARS')
plt.ylabel('Net salary in ARS')

plt.tight_layout()

# %% [markdown]
# - Habiendo ajustado las dos columnas de interés a un modelo lineal, se observa que, *para la mayoría de los valores*, **existe una relación lineal** entre el salario bruto y neto del dataset.
# - Se siguen observando datos alejados del modelo.
# - Se observan valores para salario neto por debajo del mínimo vital y móvil (outliers).
# - El ratio entre las variables de interés aumenta a medida que aumenta el valor de salario bruto.
# - Dicha relación se comporta diferente (se observa una pendiente más pronunciada) para la sub-población de part-times.

# %% [markdown]
# Sólo algunas de los descuentos y deducciones que se ven involucrados en el cálculo del sueldo bruto al neto son:
#
# - Aportes jubilatorios *(en diferentes porcentajes)*
# - Aportes a obra social o medicina pre-paga *(en diferentes porcentajes)*
# - Aportes a sindicato *(en diferentes porcentajes)*
# - Impuesto a las ganancias
# - Deducciones familiares
#     - Matrimonio
#     - Hijos *(diferente por cantidad de hijos, para hijo con discapacidad)*
# - Deducción por alquiler *(diferentes porcentajes)*
# - Seguro de vida *(diferentes porcentajes)*
# - Bienes inmuebles *(diferentes porcentajes)*
# - Zona (desfavorable, patagónico)
#
# Dado que no se cuenta con información al respecto en el dataset, y estimar un valor sería complejo e impreciso,
# **se opta por analizar el salario BRUTO para los datos de interés**.

# %% [markdown]
# #### Filtrado de filas para salarios (ejercicio 2, item 2)
#
# Se remueven aquellas entradas para las que $\text{salario_bruto} < \text{salario_neto}$

# %%
df.size, df_without_wrong_salaries_ratio.size
# Out:
# (59780, 51898)

# %%
df = df_without_wrong_salaries_ratio

# %% [markdown]
# ### Outliers (ejercicio 2, item 2)

# %% [markdown]
# #### inferior
#
# Se define el límite inferior para descarte de outliers como sigue:
#
# ##### full-time
#
# - Valores por debajo del **salario mínimo vital y móvil en Argentina en el año correspondiente al dataset (2022)**:
#     - ARS $61953 [Según el Consejo Nac del Empleo, la Productividad y el Salario Mínimo, Vital y Móvil](https://www.argentina.gob.ar/trabajo/consejodelsalario)
# > Se aplica el mínimo a ambas columnas (neto y bruto)

# %%
min_full_time_salary = 61_953

gross_salary_mask = df_full_time.monthly_gross_salary > min_full_time_salary
net_salary_mask = df_full_time.monthly_net_salary > min_full_time_salary

df_full_time_without_low_outliers = df_full_time[gross_salary_mask & net_salary_mask]

# %%
df_full_time.size, df_full_time_without_low_outliers.size
# Out:
# (59780, 53074)

# %% [markdown]
# #### Histograma full-time sin outliers inferiores

# %%
f, ax = plt.subplots(2, 1, figsize=VSUBPLOTS_FIGSIZE, dpi=DPI, sharex=True)

for i, df in enumerate([df_full_time, df_full_time_without_low_outliers]):
    df_to_plot = df.monthly_gross_salary
    sns.histplot(df_to_plot, 
                 ax=ax[i],
                 color=next(MAIN_PALETTE),
                 edgecolor='black',
                 kde=True)
    
    statistics = df_to_plot.describe(include='all')

    for j, name in enumerate(['mean', 'std']):
        statistic = statistics[name]
        ax[i].axvline(statistic,
                      label=f'{name}: {human_format(statistic)}',
                      color=CATEGORICAL_PALETTE.as_hex()[-j],
                      linestyle='dashed',)
        
    for j, st in enumerate(['25%', '50%', '75%']):
        statistic = statistics[st]
        ax[i].axvline(statistic,
                      label=f'{st}: {human_format(statistic)}',
                      color=SECUENTIAL_PALETTE.as_hex()[j],
                      linestyle='dashed')
        
    if i == 0:
        ax[i].axvline(min_full_time_salary,
                      label=f'min full-time gross salary: {human_format(min_full_time_salary)}',
                      color=SECUENTIAL_PALETTE.as_hex()[j+1],
                      linestyle='dashed')
        
    ax[i].xaxis.set_major_formatter(FORMATTER)
    ax[i].grid(alpha=0.3)
    ax[i].legend()

plt.xlim(0, 3 * statistics['std'])
plt.xlabel('salary in ARS')
plt.title('removing full-time low outliers')
plt.tight_layout()

# %% [markdown]
# ##### part-time
#
# Dado que no se cuenta con información sobre las horas de dedicación aproximadas para trabajos *part-time*, y que éstos pueden ser del tipo *"freelos"* significando un ingreso extra para la persona encuestada, se determina el percentil aproximado correspondiente al valor mínimo para salarios full-time anteriormente establecido, para aplicar esta misma *proporción* al sub data set de part-time.
#
# > Cabe aclarar que los valores antes expuestos se emplean como *guía* para eliminar outliers, pero no necesariamente estos valores mínimos sean reales, suficientes, ni dignos en la práctica.

# %% [markdown]
# Se determina a qué percentile corresponde la entrada de salario cuyo valor se acerca más al límite inferior de outliers antes definido:

# %%
gross_distance_to_min_salary = df_full_time.monthly_gross_salary.apply(
    lambda x: (x - min_full_time_salary)
).apply(lambda n: -n if n < 0 else n)

gross_distance_to_min_salary.apply(human_format)
# Out:
# 0       238K
# 1       838K
# 2        58K
# 3       378K
# 4        78K
#         ...
# 5348    238K
# 5351     48K
# 5352     58K
# 5355    168K
# 5356    389K
# Name: monthly_gross_salary, Length: 4270, dtype: object

# %%
gross_min_idx = gross_distance_to_min_salary.idxmin()
human_format(gross_distance_to_min_salary.loc[gross_min_idx])
# Out:
# '347'

# %%
net_distance_to_min_salary = df_full_time.monthly_net_salary.apply(
    lambda x: (x - min_full_time_salary)
).apply(lambda n: -n if n < 0 else n)

net_distance_to_min_salary.apply(human_format)
# Out:
# 0       183K
# 1       788K
# 2        53K
# 3        62K
# 4        63K
#         ...
# 5348    232K
# 5351     29K
# 5352     28K
# 5355    129K
# 5356    236K
# Name: monthly_net_salary, Length: 4270, dtype: object

# %%
net_min_idx = gross_distance_to_min_salary.idxmin()
human_format(net_distance_to_min_salary.loc[net_min_idx])
# Out:
# '347'

# %%
df_full_time.monthly_gross_salary.rank(pct=True)
# Out:
# 0      0.55550
# 1      0.92201
# 2      0.13724
# 3      0.74731
# 4      0.18044
#          ...
# 5348   0.55550
# 5351   0.11792
# 5352   0.13724
# 5355   0.40644
# 5356   0.76253
# Name: monthly_gross_salary, Length: 4270, dtype: float64

# %%
df_full_time.monthly_net_salary.rank(pct=True)
# Out:
# 0      0.60937
# 1      0.94145
# 2      0.20410
# 3      0.02213
# 4      0.23665
#          ...
# 5348   0.72611
# 5351   0.14485
# 5352   0.14192
# 5355   0.42881
# 5356   0.72904
# Name: monthly_net_salary, Length: 4270, dtype: float64

# %%
min_full_time_gross_salary_percentile = df_full_time.monthly_gross_salary.rank(pct=True).loc[gross_min_idx]
min_full_time_net_salary_percentile = df_full_time.monthly_net_salary.rank(pct=True).loc[net_min_idx]


min_full_time_gross_salary_percentile, min_full_time_net_salary_percentile
# Out:
# (0.058782201405152223, 0.10304449648711944)

# %% [markdown]
# Dado que los datasets presentan la misma naturaleza/comportamiento, ante la incertidumbre de un valor para el límite inferior del rango de outliers para dedicación 'part-time', se aplican los percentiles antes calculado:

# %%
min_part_time_gross_salary = df_part_time.monthly_gross_salary.quantile(min_full_time_gross_salary_percentile)
min_part_time_net_salary = df_part_time.monthly_net_salary.quantile(min_full_time_net_salary_percentile)

min_part_time_gross_salary, min_part_time_net_salary
# Out:
# (24483.723653395788, 836.7166276346611)

# %%
gross_salary_mask = df_part_time.monthly_gross_salary > min_part_time_gross_salary
net_salary_mask = df_part_time.monthly_net_salary > min_part_time_gross_salary

df_part_time_without_low_outliers = df_part_time[gross_salary_mask & net_salary_mask]

# %%
df_part_time.size, df_part_time_without_low_outliers.size
# Out:
# (2828, 2492)

# %% [markdown]
# #### Histograma part-time sin outliers inferiores

# %%
f, ax = plt.subplots(2, 1, figsize=VSUBPLOTS_FIGSIZE, dpi=DPI, sharex=True)
n_bins = 100


for i, df in enumerate([df_part_time, df_part_time_without_low_outliers]):
    df_to_plot = df.monthly_gross_salary
    sns.histplot(df_to_plot,
                 bins=n_bins,
                 ax=ax[i],
                 color=next(MAIN_PALETTE),
                 kde=True)
    
    statistics = df_to_plot.describe(include='all')

    for j, name in enumerate(['mean', 'std']):
        statistic = statistics[name]
        ax[i].axvline(statistic,
                      label=f'{name}: {human_format(statistic)}',
                      color=CATEGORICAL_PALETTE.as_hex()[-j],
                      linestyle='dashed')
        
    for j, st in enumerate(['25%', '50%', '75%']):
        statistic = statistics[st]
        ax[i].axvline(statistic,
                      label=f'{st}: {human_format(statistic)}',
                      color=SECUENTIAL_PALETTE.as_hex()[j],
                      linestyle='dashed')
        
    if i == 0:
        ax[i].axvline(min_part_time_gross_salary,
                      label=f'min part-time gross salary: {human_format(min_part_time_gross_salary)}',
                      color=SECUENTIAL_PALETTE.as_hex()[j+1],
                      linestyle='dashed')
        
    ax[i].xaxis.set_major_formatter(FORMATTER)
    ax[i].grid(alpha=0.3)
    ax[i].legend()

plt.xlim(0, 3 * statistics['std'])
plt.xlabel('salary in ARS')
plt.title('removing part-time low outliers')
plt.tight_layout()

# %% [markdown]
# Debido a la complejidad de análisis y comparación de sueldos a lo largo del tiempo en Argentina, por las fluctuaciones en las variables económicas, se trabaja con la conversión a dólar estado unidense dado por un valor *"en el medio"* de los valores medios de las cotizaciones *oficial* y *blue* durante el año 2022.
#
# > A sabiendas de que el dolar oficial no es en la práctica la cotización mayoritariamente empleada, mientras que la cotización blue no está regulada.

# %%
def ars_to_usd(ars: float) -> float:
    """
    ARS to USD conversion according to https://dolarhistorico.com/cotizacion-dolar-oficial/2022
    and https://dolarhistorico.com/cotizacion-dolar-blue/2022
    """
    ars_per_usd_blue = (347 + 343)/2
    ars_per_usd_oficial = (184.12 + 175.12)/2
    ars_per_usd = (ars_per_usd_blue + ars_per_usd_oficial) / 2
    return ars / ars_per_usd

# %%
df_full_time = df_full_time_without_low_outliers
df_part_time = df_part_time_without_low_outliers

# %%
frames = [df_part_time, df_full_time]
df = pd.concat(frames)

# %%
# this cell needs to be run manually ! SettingWithCopyWarning does not disappear :'(
df['usd_monthly_gross_salary'] = df.monthly_gross_salary.apply(ars_to_usd)
df['usd_monthly_net_salary'] = df.monthly_net_salary.apply(ars_to_usd)

# %% [markdown]
# #### superior
#
# ##### full-time
#
# La regla de $n \sigma$, $n \in \mathbb{Z}$ a la derecha del valor medio puede resultar una buena forma de eliminar outliers a la derecha de $\mu$, sin embargo:
# - es sabido que un salario en IT puede alcanzar variados y *elevados* valores
# - contemplando algunos pocos, pero muy elevados valores, éstos pueden desplazar de manera significativa los estadísticos del dataset (hacia la derecha).
#
# De manera que, teniendo en cuenta que el enfoque propuesto está fuertemente ligado a los **lenguajes de programación** del stack de las personas encuestadas vs sus salarios, se confecciona el siguiente procedimiento para eliminar outliers superiores:

# %% [markdown]
# Se fija como referencia de salarios elevados el top de tecnologías mejores pagas en IT de la [encuesta de Stackoverflow 2022](https://survey.stackoverflow.co/2022/):

# %%
TOP_TECH_2022_SURVEY = {'Clojure': 106_644, 'Erlang': 103_000, 'F#': 95_526, 'LISP': 95_000, 'Ruby': 93_000,
                         'Elixir': 92_959, 'Scala': 92_780, 'Perl': 90_073, 'Go': 89_204, 'Rust': 87_047,
                         'OCaml': 86_948, 'Groovy': 85_320, 'Crystal': 84_690, 'Objective-C': 83_165,
                         'Bash/Shell': 81_666, 'Haskell': 80_250, 'Fortran': 80_000, 'Lua': 79_568,
                         'Swift': 78_468, 'PowerShell': 78_084, 'Julia': 77_966, 'APL': 75_932, 'COBOL': 75_592,
                         'Assembly': 75_000, 'Python': 71_105, 'Solidity': 70_368, 'TypeScript': 70_276, 'C#': 69_516,
                         'Kotlin': 69_318, 'SQL': 69_108, 'C++': 68_000, 'R': 67_734, 'C': 67_186, 'JavaScript': 65_580,
                         'Java': 64_572, 'SAS': 64_243, 'Delphi': 63_984, 'HTML/CSS': 63_984, 'VBA': 62_328,
                         'MATLAB': 57_588, 'PHP': 50_496, 'Dart': 43_724,}

# %%
def salary_in_top_tech(tools: list[str]) -> float:
    """
    Return the max salary value if any tool name is in the top tech tools 2022 survey
    """
    top_tools_salaries = []
    for tool in tools:
        for top_tech in TOP_TECH_2022_SURVEY.keys():
            if tool in top_tech.lower():
                top_tools_salaries.append(TOP_TECH_2022_SURVEY[top_tech] / 12)  # anual to monthly
    if not top_tools_salaries:
        return np.nan
    return max(top_tools_salaries)

# %% [markdown]
# Se crea una nueva columna a fin de comparar el máximo salario de tecnologías extraído de la encuesta 2022 de Stackoverflow con los salarios en análisis, así como un ratio entre estos dos últimos, para poder así establecer si se trata de un salario elevado factible o no:

# %%
df['mean_salary_in_top_tech'] = df.list_of_tools_programming_languages.apply(salary_in_top_tech)
df['ratio_gross_top_tech'] = df.usd_monthly_gross_salary.div(df.mean_salary_in_top_tech)

# %%
df.columns
# Out:
# Index(['work_dedication', 'monthly_gross_salary', 'monthly_net_salary',
#        'salary_comparison_last_semester', 'profile_years_experience',
#        'list_of_tools_platform', 'list_of_tools_programming_languages',
#        'list_of_tools_frameworks', 'list_of_tools_data_bases',
#        'list_of_tools_qa_testing', 'profile_level_study', 'profile_gender',
#        'profile_experience_range', 'list_of_normalized_languages',
#        'usd_monthly_gross_salary', 'usd_monthly_net_salary',
#        'mean_salary_in_top_tech', 'ratio_gross_top_tech'],
#       dtype='object')

# %%
for col in ['usd_monthly_gross_salary', 'usd_monthly_net_salary', 'mean_salary_in_top_tech', 'ratio_gross_top_tech']:
    columns_of_interest.append(col) 

columns_of_interest = list(set(columns_of_interest))

# %%
df = df[columns_of_interest]

# %% [markdown]
# ##### Vista formateada de mayores salarios full-time

# %%
df_part_time = df.groupby('work_dedication').get_group('part-time')
df_full_time = df.groupby('work_dedication').get_group('full-time')

# %%
higher_than_mu_mask = df_full_time.monthly_gross_salary > df_full_time.monthly_gross_salary.mean()

df_full_time[
    higher_than_mu_mask
].sort_values(
    by='usd_monthly_gross_salary', ascending=False
)[
    ['usd_monthly_gross_salary', 'list_of_tools_programming_languages', 'mean_salary_in_top_tech', 'ratio_gross_top_tech']
].head(50).style.format(
    {col: human_format for col in ['usd_monthly_gross_salary', 'mean_salary_in_top_tech']},  # '${:,.2f}'},
    precision=1,
).bar(subset=['usd_monthly_gross_salary', 'mean_salary_in_top_tech'], color='green'
     ).applymap(lambda x: 'background-color: red' if x > 1.3 else '', subset=['ratio_gross_top_tech'])
# Out:
# <style type="text/css">
# #T_4b6e1_row0_col0, #T_4b6e1_row15_col2, #T_4b6e1_row16_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, green 100.0%, transparent 100.0%);
# }
# #T_4b6e1_row0_col2, #T_4b6e1_row11_col2, #T_4b6e1_row26_col2, #T_4b6e1_row27_col2, #T_4b6e1_row31_col2, #T_4b6e1_row32_col2, #T_4b6e1_row45_col2, #T_4b6e1_row49_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, green 66.7%, transparent 66.7%);
# }
# #T_4b6e1_row0_col3, #T_4b6e1_row1_col3, #T_4b6e1_row2_col3, #T_4b6e1_row3_col3, #T_4b6e1_row4_col3, #T_4b6e1_row5_col3, #T_4b6e1_row6_col3, #T_4b6e1_row7_col3, #T_4b6e1_row8_col3, #T_4b6e1_row9_col3, #T_4b6e1_row10_col3, #T_4b6e1_row11_col3, #T_4b6e1_row12_col3, #T_4b6e1_row13_col3, #T_4b6e1_row14_col3, #T_4b6e1_row17_col3, #T_4b6e1_row19_col3, #T_4b6e1_row20_col3, #T_4b6e1_row24_col3, #T_4b6e1_row25_col3, #T_4b6e1_row26_col3, #T_4b6e1_row27_col3, #T_4b6e1_row31_col3, #T_4b6e1_row32_col3, #T_4b6e1_row34_col3, #T_4b6e1_row36_col3, #T_4b6e1_row38_col3, #T_4b6e1_row44_col3, #T_4b6e1_row45_col3, #T_4b6e1_row46_col3 {
#   background-color: red;
# }
# #T_4b6e1_row1_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, green 28.6%, transparent 28.6%);
# }
# #T_4b6e1_row1_col2, #T_4b6e1_row4_col2, #T_4b6e1_row8_col2, #T_4b6e1_row18_col2, #T_4b6e1_row21_col2, #T_4b6e1_row23_col2, #T_4b6e1_row28_col2, #T_4b6e1_row29_col2, #T_4b6e1_row30_col2, #T_4b6e1_row40_col2, #T_4b6e1_row41_col2, #T_4b6e1_row48_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, green 83.6%, transparent 83.6%);
# }
# #T_4b6e1_row2_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, green 13.1%, transparent 13.1%);
# }
# #T_4b6e1_row2_col2, #T_4b6e1_row6_col2, #T_4b6e1_row33_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, green 76.6%, transparent 76.6%);
# }
# #T_4b6e1_row3_col0, #T_4b6e1_row4_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, green 11.8%, transparent 11.8%);
# }
# #T_4b6e1_row3_col2, #T_4b6e1_row13_col2, #T_4b6e1_row14_col2, #T_4b6e1_row25_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, green 61.5%, transparent 61.5%);
# }
# #T_4b6e1_row5_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, green 11.2%, transparent 11.2%);
# }
# #T_4b6e1_row5_col2, #T_4b6e1_row17_col2, #T_4b6e1_row19_col2, #T_4b6e1_row24_col2, #T_4b6e1_row34_col2, #T_4b6e1_row36_col2, #T_4b6e1_row38_col2, #T_4b6e1_row46_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, green 65.9%, transparent 65.9%);
# }
# #T_4b6e1_row6_col0, #T_4b6e1_row7_col0, #T_4b6e1_row8_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, green 10.7%, transparent 10.7%);
# }
# #T_4b6e1_row7_col2, #T_4b6e1_row37_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, green 87.0%, transparent 87.0%);
# }
# #T_4b6e1_row9_col0, #T_4b6e1_row10_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, green 10.4%, transparent 10.4%);
# }
# #T_4b6e1_row9_col2, #T_4b6e1_row12_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, green 64.8%, transparent 64.8%);
# }
# #T_4b6e1_row10_col2, #T_4b6e1_row22_col2, #T_4b6e1_row35_col2, #T_4b6e1_row42_col2, #T_4b6e1_row43_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, green 87.2%, transparent 87.2%);
# }
# #T_4b6e1_row11_col0, #T_4b6e1_row12_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, green 10.0%, transparent 10.0%);
# }
# #T_4b6e1_row13_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, green 9.7%, transparent 9.7%);
# }
# #T_4b6e1_row14_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, green 9.6%, transparent 9.6%);
# }
# #T_4b6e1_row15_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, green 9.3%, transparent 9.3%);
# }
# #T_4b6e1_row16_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, green 9.1%, transparent 9.1%);
# }
# #T_4b6e1_row17_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, green 9.0%, transparent 9.0%);
# }
# #T_4b6e1_row18_col0, #T_4b6e1_row19_col0, #T_4b6e1_row20_col0, #T_4b6e1_row21_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, green 8.9%, transparent 8.9%);
# }
# #T_4b6e1_row20_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, green 65.2%, transparent 65.2%);
# }
# #T_4b6e1_row22_col0, #T_4b6e1_row23_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, green 8.8%, transparent 8.8%);
# }
# #T_4b6e1_row24_col0, #T_4b6e1_row25_col0, #T_4b6e1_row26_col0, #T_4b6e1_row27_col0, #T_4b6e1_row28_col0, #T_4b6e1_row29_col0, #T_4b6e1_row30_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, green 8.6%, transparent 8.6%);
# }
# #T_4b6e1_row31_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, green 8.5%, transparent 8.5%);
# }
# #T_4b6e1_row32_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, green 8.3%, transparent 8.3%);
# }
# #T_4b6e1_row33_col0, #T_4b6e1_row34_col0, #T_4b6e1_row35_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, green 8.2%, transparent 8.2%);
# }
# #T_4b6e1_row36_col0, #T_4b6e1_row37_col0, #T_4b6e1_row38_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, green 7.9%, transparent 7.9%);
# }
# #T_4b6e1_row39_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, green 7.8%, transparent 7.8%);
# }
# #T_4b6e1_row39_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, green 96.6%, transparent 96.6%);
# }
# #T_4b6e1_row40_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, green 7.6%, transparent 7.6%);
# }
# #T_4b6e1_row41_col0, #T_4b6e1_row42_col0, #T_4b6e1_row43_col0, #T_4b6e1_row44_col0, #T_4b6e1_row45_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, green 7.5%, transparent 7.5%);
# }
# #T_4b6e1_row44_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, green 66.0%, transparent 66.0%);
# }
# #T_4b6e1_row46_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, green 7.4%, transparent 7.4%);
# }
# #T_4b6e1_row47_col0, #T_4b6e1_row48_col0, #T_4b6e1_row49_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, green 7.1%, transparent 7.1%);
# }
# #T_4b6e1_row47_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, green 81.6%, transparent 81.6%);
# }
# </style>
# <table id="T_4b6e1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4b6e1_level0_col0" class="col_heading level0 col0" >usd_monthly_gross_salary</th>
#       <th id="T_4b6e1_level0_col1" class="col_heading level0 col1" >list_of_tools_programming_languages</th>
#       <th id="T_4b6e1_level0_col2" class="col_heading level0 col2" >mean_salary_in_top_tech</th>
#       <th id="T_4b6e1_level0_col3" class="col_heading level0 col3" >ratio_gross_top_tech</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4b6e1_level0_row0" class="row_heading level0 row0" >4507</th>
#       <td id="T_4b6e1_row0_col0" class="data row0 col0" >107K</td>
#       <td id="T_4b6e1_row0_col1" class="data row0 col1" >['html', 'javascript', 'php', 'python', 'typescript']</td>
#       <td id="T_4b6e1_row0_col2" class="data row0 col2" >6K</td>
#       <td id="T_4b6e1_row0_col3" class="data row0 col3" >18.0</td>
#     </tr>
#     <tr>
#       <th id="T_4b6e1_level0_row1" class="row_heading level0 row1" >3086</th>
#       <td id="T_4b6e1_row1_col0" class="data row1 col0" >30K</td>
#       <td id="T_4b6e1_row1_col1" class="data row1 col1" >['go', 'python']</td>
#       <td id="T_4b6e1_row1_col2" class="data row1 col2" >7K</td>
#       <td id="T_4b6e1_row1_col3" class="data row1 col3" >4.1</td>
#     </tr>
#     <tr>
#       <th id="T_4b6e1_level0_row2" class="row_heading level0 row2" >2388</th>
#       <td id="T_4b6e1_row2_col0" class="data row2 col0" >14K</td>
#       <td id="T_4b6e1_row2_col1" class="data row2 col1" >['bash/shell', 'css', 'html', 'javascript', 'typescript']</td>
#       <td id="T_4b6e1_row2_col2" class="data row2 col2" >7K</td>
#       <td id="T_4b6e1_row2_col3" class="data row2 col3" >2.1</td>
#     </tr>
#     <tr>
#       <th id="T_4b6e1_level0_row3" class="row_heading level0 row3" >975</th>
#       <td id="T_4b6e1_row3_col0" class="data row3 col0" >13K</td>
#       <td id="T_4b6e1_row3_col1" class="data row3 col1" >['java']</td>
#       <td id="T_4b6e1_row3_col2" class="data row3 col2" >5K</td>
#       <td id="T

# %% [markdown]
# Se pueden visualizar algunos salarios *elevados* respecto al $\mu$ del dataset, que se condicen con los salarios factibles de referencia, y que:
# - aplicando la regla de las desviaciones estandard, se hubiesen descartado como outliers
# - conservandolos *(véase salario del index 4507 de 81k usd)* desplazan los estadísticos hacia la derecha
#
# Se descartan entonces las entradas con salarios elevados (por encima de $\mu$), que presentan un ratio respecto a la refencia de **más de 1.3** (dado que los valores de referencia son un "top"):

# %% [markdown]
# ##### Vista formateada de mayores salarios full-time y sus lenguajes de programación

# %%
no_fake_gross_high_salary_mask = df_full_time.ratio_gross_top_tech < 1.1

df_full_time_without_fake_high_salaries = df_full_time[no_fake_gross_high_salary_mask]
df_full_time_without_fake_high_salaries.sort_values(
    by='usd_monthly_gross_salary', ascending=False
)[
    ['usd_monthly_gross_salary', 'list_of_tools_programming_languages']
].head(30).style.format(
    {'usd_monthly_gross_salary': human_format},  # '${:,.2f}'},
    precision=1,
).bar(subset=['usd_monthly_gross_salary'], color='green')
# Out:
# <style type="text/css">
# #T_38b2d_row0_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, green 100.0%, transparent 100.0%);
# }
# #T_38b2d_row1_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, green 86.8%, transparent 86.8%);
# }
# #T_38b2d_row2_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, green 86.2%, transparent 86.2%);
# }
# #T_38b2d_row3_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, green 83.4%, transparent 83.4%);
# }
# #T_38b2d_row4_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, green 83.3%, transparent 83.3%);
# }
# #T_38b2d_row5_col0, #T_38b2d_row6_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, green 82.8%, transparent 82.8%);
# }
# #T_38b2d_row7_col0, #T_38b2d_row8_col0, #T_38b2d_row9_col0, #T_38b2d_row10_col0, #T_38b2d_row11_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, green 78.9%, transparent 78.9%);
# }
# #T_38b2d_row12_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, green 76.9%, transparent 76.9%);
# }
# #T_38b2d_row13_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, green 72.8%, transparent 72.8%);
# }
# #T_38b2d_row14_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, green 72.5%, transparent 72.5%);
# }
# #T_38b2d_row15_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, green 71.6%, transparent 71.6%);
# }
# #T_38b2d_row16_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, green 71.0%, transparent 71.0%);
# }
# #T_38b2d_row17_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, green 70.9%, transparent 70.9%);
# }
# #T_38b2d_row18_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, green 69.2%, transparent 69.2%);
# }
# #T_38b2d_row19_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, green 69.1%, transparent 69.1%);
# }
# #T_38b2d_row20_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, green 68.7%, transparent 68.7%);
# }
# #T_38b2d_row21_col0, #T_38b2d_row22_col0, #T_38b2d_row23_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, green 67.1%, transparent 67.1%);
# }
# #T_38b2d_row24_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, green 66.3%, transparent 66.3%);
# }
# #T_38b2d_row25_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, green 65.1%, transparent 65.1%);
# }
# #T_38b2d_row26_col0, #T_38b2d_row27_col0, #T_38b2d_row28_col0, #T_38b2d_row29_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, green 63.1%, transparent 63.1%);
# }
# </style>
# <table id="T_38b2d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_38b2d_level0_col0" class="col_heading level0 col0" >usd_monthly_gross_salary</th>
#       <th id="T_38b2d_level0_col1" class="col_heading level0 col1" >list_of_tools_programming_languages</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_38b2d_level0_row0" class="row_heading level0 row0" >3253</th>
#       <td id="T_38b2d_row0_col0" class="data row0 col0" >10K</td>
#       <td id="T_38b2d_row0_col1" class="data row0 col1" >['c', 'c++', 'dart', 'go', 'java', 'javascript', 'python']</td>
#     </tr>
#     <tr>
#       <th id="T_38b2d_level0_row1" class="row_heading level0 row1" >1471</th>
#       <td id="T_38b2d_row1_col0" class="data row1 col0" >8K</td>
#       <td id="T_38b2d_row1_col1" class="data row1 col1" >['bash/shell', 'go', 'javascript', 'python', 'scala', 'sql']</td>
#     </tr>
#     <tr>
#       <th id="T_38b2d_level0_row2" class="row_heading level0 row2" >3920</th>
#       <td id="T_38b2d_row2_col0" class="data row2 col0" >8K</td>
#       <td id="T_38b2d_row2_col1" class="data row2 col1" >['go', 'erlang', 'java', 'python', 'scala', 'sql']</td>
#     </tr>
#     <tr>
#       <th id="T_38b2d_level0_row3" class="row_heading level0 row3" >549</th>
#       <td id="T_38b2d_row3_col0" class="data row3 col0" >8K</td>
#       <td id="T_38b2d_row3_col1" class="data row3 col1" >['bash/shell', 'go', 'python']</td>
#     </tr>
#     <tr>
#       <th id="T_38b2d_level0_row4" class="row_heading level0 row4" >4217</th>
#       <td id="T_38b2d_row4_col0" class="data row4 col0" >8K</td>
#       <td id="T_38b2d_row4_col1" class="data row4 col1" >['go', 'typescript']</td>
#     </tr>
#     <tr>
#       <th id="T_38b2d_level0_row5" class="row_heading level0 row5" >3792</th>
#       <td id="T_38b2d_row5_col0" class="data row5 col0" >8K</td>
#       <td id="T_38b2d_row5_col1" class="data row5 col1" >['go', 'ruby', 'typescript']</td>
#     </tr>
#     <tr>
#       <th id="T_38b2d_level0_row6" class="row_heading level0 row6" >341</th>
#       <td id="T_38b2d_row6_col0" class="data row6 col0" >8K</td>
#       <td id="T_38b2d_row6_col1" class="data row6 col1" >['go', 'python', 'ruby', 'rust', 'typescript']</td>
#     </tr>
#     <tr>
#       <th id="T_38b2d_level0_row7" class="row_heading level0 row7" >3782</th>
#       <td id="T_38b2d_row7_col0" class="data row7 col0" >8K</td>
#       <td id="T_38b2d_row7_col1" class="data row7 col1" >['javascript', 'python', 'scala']</td>
#     </tr>
#     <tr>
#       <th id="T_38b2d_level0_row8" class="row_heading level0 row8" >3520</th>
#       <td id="T_38b2d_row8_col0" class="data row8 col0" >8K</td>
#       <td id="T_38b2d_row8_col1" class="data row8 col1" >['c#', 'groovy', 'html', 'javascript', 'python', 'sql']</td>
#     </tr>
#     <tr>
#       <th id="T_38b2d_level0_row9" class="row_heading level0 row9" >1454</th>
#       <td id="T_38b2d_row9_col0" class="data row9 col0" >8K</td>
#       <td id="T_38b2d_row9_col1" class="data row9 col1" >['go', 'java', 'typescript']</td>
#     </tr>
#     <tr>
#       <th id="T_38b2d_level0_row10" class="row_heading level0 row10" >391</th>
#       <td id="T_38b2d_row10_col0" class="data row10 col0" >8K</td>
#       <td id="T_38b2d_row10_col1" class="data row10 col1" >['bash/shell', 'javascript', 'rust', 'sql', 'typescript']</td>
#     </tr>
#     <tr>
#       <th id="T_38b2d_level0_row11" class="row_heading level0 row11" >2767</th>
#       <td id="T_38b2d_row11_col0" class="data row11 col0" >8K</td>
#       <td id="T_38b2d_row11_col1" class="data row11 col1" >['go', 'javascript', 'python', 'sql', 'typescript']</td>
#     </tr>
#     <tr>
#       <th id="T_38b2d_level0_row12" class="row_heading level0 row12" >4841</th>
#       <td id="T_38b2d_row12_col0" class="data row12 col0" >7K</td>
#       <td id="T_38b2d_row12_col1" class="data row12 col1" >['bash/shell', 'go', 'java', 'javascript', 'swift', 'typescript']</td>
#     </tr>
#     <tr>
#       <th id="T_38b2d_level0_row13" class="row_heading level0 row13" >488</th>
#       <td id="T_38b2d_row13_col0" class="data row13 col0" >7K</td>
#       <td id="T_38b2d_row13_col1" class="data row13 col1" >['bash/shell', 'javascript', 'python', 'sql', 'typescript']</td>
#     </tr>
#     <tr>
#       <th id="T_38b2d_level0_row14" class="row_heading level0 row14" >656</th>
#       <td id="T_38b2d_row14_col0" class="data row14 col0" >7K</td>
#       <td id="T_38b2d_row14_col1" class="data row14 col1" >['groovy', 'python']</td>
#     </tr>
#     <tr>
#       <th id="T_38b2d_level0_row15" class="row_heading level0 row15" >5223</th>
#       <td id="T_38b2d_row15_col0" class="data row15 col0" >7K</td>
#       <td id="T_38b2d_row15_col1" class="data row15 col1" >['bash/shell', 'go', 'html', 'javascript', 'python', 'ruby', 'typescript']</td>
#     </tr>
#     <tr>
#       <th id="T_38b2d_level0_row16" class="row_heading level0 row16" >3378</th>
#       <td id="T_38b2d_row16_col0" class="data row16 col0" >7K</td>
#       <td id="T_38b2d_row16_col1" class="data row16 col1" >['bash/shell', 'go', 'python']</td>
#     </tr>
#     <tr>
#       <th id="T_38b2d_level0_row17" class="row_heading level0 row17" >1884</th>
#       <td id="T_38b2d_row17_col0" class="data row17 col0" >7K</td>
#       <td id="T_38b2d_row17_col1" class="data row17 col1" >['javascript', 'swift']</td>
#     </tr>
#     <tr>
#       <th id="T_38b2d_level0_row18" class="row_heading level0 row18" >3781</th>
#       <td id="T_38b2d_row18_col0" class="data row18 col0" >7K</td>
#       <td id="T_38b2d_row18_col1" class="data row18 col1" >['go', 'java', 'sql']</td>
#     </tr>
#     <tr>
#       <th id="T_38b2d_level0_row19" class="row_heading level0 row19" >1599</th>
#       <td id="T_38b2d_row19_col0" class="

# %%
df_full_time.size, df_full_time_without_fake_high_salaries.size
# Out:
# (68238, 65574)

# %%
max_full_time_gross_salary = df_full_time_without_fake_high_salaries.usd_monthly_gross_salary.max()

# %% [markdown]
# #### Histograma full-time sin outliers superiores

# %%
f, ax = plt.subplots(2, 1, figsize=VSUBPLOTS_FIGSIZE, dpi=DPI, sharex=True)

for i, df in enumerate([df_full_time, df_full_time_without_fake_high_salaries]):
    df_to_plot = df.usd_monthly_gross_salary
    sns.histplot(df_to_plot, 
                 ax=ax[i],
                 color=next(MAIN_PALETTE),
                kde=True)
    
    statistics = df_to_plot.describe(include='all')

    for j, name in enumerate(['mean', 'std']):
        statistic = statistics[name]
        ax[i].axvline(statistic,
                      label=f'{name}: {human_format(statistic)}',
                      color=CATEGORICAL_PALETTE.as_hex()[-j],
                      linestyle='dashed')
        
    for j, st in enumerate(['25%', '50%', '75%']):
        statistic = statistics[st]
        ax[i].axvline(statistic,
                      label=f'{st}: {human_format(statistic)}',
                      color=SECUENTIAL_PALETTE.as_hex()[j],
                      linestyle='dashed')
        
    if i == 0:
        ax[i].axvline(max_full_time_gross_salary,
                      label=f'max_full_time_gross_salary: {human_format(max_full_time_gross_salary)}',
                      color=SECUENTIAL_PALETTE.as_hex()[j+1],
                      linestyle='dashed')
        
        three_sigmas = 3 * statistics['std']
        
        ax[i].axvline(three_sigmas,
                  label=f'3 $\sigma$: {human_format(three_sigmas)}',
                  color=SECUENTIAL_PALETTE.as_hex()[-j],
                  linestyle='dashed')
        
    ax[i].xaxis.set_major_formatter(FORMATTER)
    ax[i].grid(alpha=0.3)
    ax[i].legend()

plt.xlim(0, 1.1 * max_full_time_gross_salary)
plt.xlabel('salary in USD')
plt.title('removing full-time high outliers')
plt.tight_layout()

# %% [markdown]
# ##### part-time

# %% [markdown]
# Se determina a qué percentile corresponde la entrada de salario cuyo valor se acerca más al límite superior de outliers antes definido:

# %%
distance_to_max_salary = df_full_time.usd_monthly_gross_salary.apply(
    lambda x: (x - max_full_time_gross_salary)
).apply(lambda n: -n if n < 0 else n)
distance_to_max_salary
# Out:
# 0      8520.45290
# 1      6233.08299
# 2      9206.66387
# 4      9130.41821
# 5      7250.96260
#           ...
# 5348   8520.45290
# 5351   9244.78670
# 5352   9206.66387
# 5355   8787.31272
# 5356   7944.84007
# Name: usd_monthly_gross_salary, Length: 3791, dtype: float64

# %%
min_idx = distance_to_max_salary.idxmin()
min_idx, distance_to_max_salary.loc[min_idx]
# Out:
# (3253, 0.0)

# %%
df_full_time.usd_monthly_gross_salary.rank(pct=True)
# Out:
# 0      0.52981
# 1      0.91981
# 2      0.08019
# 4      0.12662
# 5      0.85888
#          ...
# 5348   0.52981
# 5351   0.05922
# 5352   0.08019
# 5355   0.37167
# 5356   0.75257
# Name: usd_monthly_gross_salary, Length: 3791, dtype: float64

# %%
max_full_time_salary_percentile = df_full_time.usd_monthly_gross_salary.rank(pct=True).loc[min_idx]
max_full_time_salary_percentile
# Out:
# 0.9957794777103667

# %% [markdown]
# Dado que los datasets presentan la misma naturaleza/comportamiento, ante la incertidumbre de un valor para el límite inferior del rango de outliers para dedicación 'part-time', se aplica el percentil ~$0.9956$ antes calculado:

# %%
max_part_time_gross_salary = df_part_time.usd_monthly_gross_salary.quantile(max_full_time_salary_percentile)
max_part_time_gross_salary
# Out:
# 3633.575488903682

# %% [markdown]
# ##### Vista formateada mayores salarios y sus lenguajes de programación sin outliers superiores

# %%
no_fake_high_salary_mask = df_part_time.usd_monthly_gross_salary < max_part_time_gross_salary
df_part_time_without_fake_high_salaries = df_part_time[no_fake_high_salary_mask]
df_part_time_without_fake_high_salaries.sort_values(
    by='usd_monthly_gross_salary', ascending=False
)[
    ['usd_monthly_gross_salary', 'list_of_tools_programming_languages']
].head(30).style.format(
    {'usd_monthly_gross_salary': human_format},  # '${:,.2f}'},
    precision=1,
).bar(subset=['usd_monthly_gross_salary'], color='green')
# Out:
# <style type="text/css">
# #T_8bf96_row0_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, green 100.0%, transparent 100.0%);
# }
# #T_8bf96_row1_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, green 91.8%, transparent 91.8%);
# }
# #T_8bf96_row2_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, green 88.9%, transparent 88.9%);
# }
# #T_8bf96_row3_col0, #T_8bf96_row4_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, green 77.8%, transparent 77.8%);
# }
# #T_8bf96_row5_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, green 66.7%, transparent 66.7%);
# }
# #T_8bf96_row6_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, green 63.3%, transparent 63.3%);
# }
# #T_8bf96_row7_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, green 54.8%, transparent 54.8%);
# }
# #T_8bf96_row8_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, green 51.1%, transparent 51.1%);
# }
# #T_8bf96_row9_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, green 41.7%, transparent 41.7%);
# }
# #T_8bf96_row10_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, green 39.6%, transparent 39.6%);
# }
# #T_8bf96_row11_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, green 38.9%, transparent 38.9%);
# }
# #T_8bf96_row12_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, green 36.6%, transparent 36.6%);
# }
# #T_8bf96_row13_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, green 36.4%, transparent 36.4%);
# }
# #T_8bf96_row14_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, green 35.6%, transparent 35.6%);
# }
# #T_8bf96_row15_col0, #T_8bf96_row16_col0, #T_8bf96_row17_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, green 33.3%, transparent 33.3%);
# }
# #T_8bf96_row18_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, green 29.8%, transparent 29.8%);
# }
# #T_8bf96_row19_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, green 29.5%, transparent 29.5%);
# }
# #T_8bf96_row20_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, green 28.2%, transparent 28.2%);
# }
# #T_8bf96_row21_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, green 28.1%, transparent 28.1%);
# }
# #T_8bf96_row22_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, green 27.8%, transparent 27.8%);
# }
# #T_8bf96_row23_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, green 27.1%, transparent 27.1%);
# }
# #T_8bf96_row24_col0, #T_8bf96_row25_col0, #T_8bf96_row26_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, green 26.7%, transparent 26.7%);
# }
# #T_8bf96_row27_col0, #T_8bf96_row28_col0, #T_8bf96_row29_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, green 25.6%, transparent 25.6%);
# }
# </style>
# <table id="T_8bf96">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8bf96_level0_col0" class="col_heading level0 col0" >usd_monthly_gross_salary</th>
#       <th id="T_8bf96_level0_col1" class="col_heading level0 col1" >list_of_tools_programming_languages</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8bf96_level0_row0" class="row_heading level0 row0" >513</th>
#       <td id="T_8bf96_row0_col0" class="data row0 col0" >3K</td>
#       <td id="T_8bf96_row0_col1" class="data row0 col1" >['html']</td>
#     </tr>
#     <tr>
#       <th id="T_8bf96_level0_row1" class="row_heading level0 row1" >964</th>
#       <td id="T_8bf96_row1_col0" class="data row1 col0" >3K</td>
#       <td id="T_8bf96_row1_col1" class="data row1 col1" >['python', 'r']</td>
#     </tr>
#     <tr>
#       <th id="T_8bf96_level0_row2" class="row_heading level0 row2" >3801</th>
#       <td id="T_8bf96_row2_col0" class="data row2 col0" >3K</td>
#       <td id="T_8bf96_row2_col1" class="data row2 col1" >['bash/shell', 'python', 'sql']</td>
#     </tr>
#     <tr>
#       <th id="T_8bf96_level0_row3" class="row_heading level0 row3" >4385</th>
#       <td id="T_8bf96_row3_col0" class="data row3 col0" >3K</td>
#       <td id="T_8bf96_row3_col1" class="data row3 col1" >['.net', 'arduino', 'bash/shell', 'c#', 'html', 'javascript', 'sql']</td>
#     </tr>
#     <tr>
#       <th id="T_8bf96_level0_row4" class="row_heading level0 row4" >2189</th>
#       <td id="T_8bf96_row4_col0" class="data row4 col0" >3K</td>
#       <td id="T_8bf96_row4_col1" class="data row4 col1" >['php', 'python']</td>
#     </tr>
#     <tr>
#       <th id="T_8bf96_level0_row5" class="row_heading level0 row5" >1736</th>
#       <td id="T_8bf96_row5_col0" class="data row5 col0" >2K</td>
#       <td id="T_8bf96_row5_col1" class="data row5 col1" >['go', 'html', 'javascript', 'php', 'python']</td>
#     </tr>
#     <tr>
#       <th id="T_8bf96_level0_row6" class="row_heading level0 row6" >4329</th>
#       <td id="T_8bf96_row6_col0" class="data row6 col0" >2K</td>
#       <td id="T_8bf96_row6_col1" class="data row6 col1" >['groovy', 'html', 'java', 'javascript', 'sql']</td>
#     </tr>
#     <tr>
#       <th id="T_8bf96_level0_row7" class="row_heading level0 row7" >1325</th>
#       <td id="T_8bf96_row7_col0" class="data row7 col0" >2K</td>
#       <td id="T_8bf96_row7_col1" class="data row7 col1" >['python']</td>
#     </tr>
#     <tr>
#       <th id="T_8bf96_level0_row8" class="row_heading level0 row8" >4321</th>
#       <td id="T_8bf96_row8_col0" class="data row8 col0" >2K</td>
#       <td id="T_8bf96_row8_col1" class="data row8 col1" >['bash/shell', 'css', 'dart', 'html', 'javascript', 'matlab', 'python', 'r', 'scala', 'sql', 'typescript']</td>
#     </tr>
#     <tr>
#       <th id="T_8bf96_level0_row9" class="row_heading level0 row9" >796</th>
#       <td id="T_8bf96_row9_col0" class="data row9 col0" >1K</td>
#       <td id="T_8bf96_row9_col1" class="data row9 col1" >['php', 'scala']</td>
#     </tr>
#     <tr>
#       <th id="T_8bf96_level0_row10" class="row_heading level0 row10" >2060</th>
#       <td id="T_8bf96_row10_col0" class="data row10 col0" >1K</td>
#       <td id="T_8bf96_row10_col1" class="data row10 col1" >['groovy', 'java', 'kotlin', 'python']</td>
#     </tr>
#     <tr>
#       <th id="T_8bf96_level0_row11" class="row_heading level0 row11" >3027</th>
#       <td id="T_8bf96_row11_col0" class="data row11 col0" >1K</td>
#       <td id="T_8bf96_row11_col1" class="data row11 col1" >['arduino', 'c', 'c++', 'python']</td>
#     </tr>
#     <tr>
#       <th id="T_8bf96_level0_row12" class="row_heading level0 row12" >2650</th>
#       <td id="T_8bf96_row12_col0" class="data row12 col0" >1K</td>
#       <td id="T_8bf96_row12_col1" class="data row12 col1" >['javascript', 'php', 'python', 'sql']</td>
#     </tr>
#     <tr>
#       <th id="T_8bf96_level0_row13" class="row_heading level0 row13" >1853</th>
#       <td id="T_8bf96_row13_col0" class="data row13 col0" >1K</td>
#       <td id="T_8bf96_row13_col1" class="data row13 col1" >['css', 'html', 'java', 'javascript', 'typescript']</td>
#     </tr>
#     <tr>
#       <th id="T_8bf96_level0_row14" class="row_heading level0 row14" >2824</th>
#       <td id="T_8bf96_row14_col0" class="data row14 col0" >1K</td>
#       <td id="T_8bf96_row14_col1" class="data row14 col1" >['arduino', 'c', 'c++', 'python']</td>
#     </tr>
#     <tr>
#       <th id="T_8bf96_level0_row15" class="row_heading level0 row15" >2979</th>
#       <td id="T_8bf96_row15_col0" class="data row15 col0" >1K</td>
#       <td id="T_8bf96_row15_col1" class="data row15 col1" >['python', 'typescript', 'haskell', 'plutus']</td>
#     </tr>
#     <tr>
#       <th id="T_8bf96_level0_row16" class="row_heading level0 row16" >3090</th>
#       <td id="T_8bf96_row16_col0" class="data row16 col0" >1K</td>
#       <td id="T_8bf96_row16_col1" class="data row16 col1" >['c', 'css', 'html', 'ruby', 'crystal']</td>
#     </tr>
#     <tr>
#       <th id="T_8bf96_level0_row17" class="row_heading level0 row17" >1958</th>
#       <td id="T_8bf96_row17_col0" class="data row17 col0" >1K</td>
#       <td id="T_8bf96_row17_col1" class="data row17 col1" >['javascript', 'python']</td>
#     </tr>
#     <tr>
#       <th id="T_8bf96_level0_row18" class="row_heading level0 row18" >2588</th>
#       <td id="T_8bf96_row18_col0" class="data row18 col0" >1K</td>
#       <td id="T_8bf96_row18_col1" class="data row18 col1" >['.net', 'css', 'html', '

# %%
df_part_time.size, df_part_time_without_fake_high_salaries.size
# Out:
# (3204, 3186)

# %% [markdown]
# ##### Histograma part-time sin outliers superiores

# %%
f, ax = plt.subplots(2, 1, figsize=VSUBPLOTS_FIGSIZE, dpi=DPI, sharex=True)
n_bins = 50

for i, df in enumerate([df_part_time, df_part_time_without_fake_high_salaries]):
    df_to_plot = df.usd_monthly_gross_salary
    sns.histplot(df_to_plot,
                 bins=n_bins,
                 ax=ax[i],
                 color=next(MAIN_PALETTE),
                kde=True)
    
    statistics = df_to_plot.describe(include='all')

    for j, name in enumerate(['mean', 'std']):
        statistic = statistics[name]
        ax[i].axvline(statistic,
                      label=f'{name}: {human_format(statistic)}',
                      color=CATEGORICAL_PALETTE.as_hex()[-j],
                      linestyle='dashed')
        
    for j, st in enumerate(['25%', '50%', '75%']):
        statistic = statistics[st]
        ax[i].axvline(statistic,
                      label=f'{st}: {human_format(statistic)}',
                      color=SECUENTIAL_PALETTE.as_hex()[j],
                      linestyle='dashed')
        
    if i == 0:
        ax[i].axvline(min_part_time_gross_salary,
                      label=f'max part-time gross salary: {human_format(max_part_time_gross_salary)}',
                      color=SECUENTIAL_PALETTE.as_hex()[j+1],
                      linestyle='dashed')
        
        three_sigmas = 3 * statistics['std']
        
        ax[i].axvline(three_sigmas,
                  label=f'3 $\sigma$: {human_format(three_sigmas)}',
                  color=SECUENTIAL_PALETTE.as_hex()[-j],
                  linestyle='dashed')
        
    ax[i].xaxis.set_major_formatter(FORMATTER)
    ax[i].grid(alpha=0.3)
    ax[i].legend()

plt.xlim(0, 1.1 * df_part_time.usd_monthly_gross_salary.max())
plt.xlabel('salary in USD')
plt.title('removing part-time high outliers')
plt.tight_layout()

# %% [markdown]
# Quedan así definidos los datasets para su visualización y análisis

# %%
df_part_time.columns
# Out:
# Index(['work_dedication', 'usd_monthly_net_salary', 'monthly_net_salary',
#        'list_of_tools_data_bases', 'mean_salary_in_top_tech', 'profile_gender',
#        'list_of_tools_qa_testing', 'ratio_gross_top_tech',
#        'profile_years_experience', 'profile_level_study',
#        'salary_comparison_last_semester', 'list_of_tools_platform',
#        'monthly_gross_salary', 'profile_experience_range',
#        'usd_monthly_gross_salary', 'list_of_tools_frameworks',
#        'list_of_tools_programming_languages', 'list_of_normalized_languages'],
#       dtype='object')

# %%
frames = [df_part_time, df_full_time]
df = pd.concat(frames)

# %% [markdown]
# ## Vista formateada dataset pre procesado

# %%
COLOR_BY_EXP_RANGE = {}

for i, years_range in enumerate(df.profile_experience_range.unique()):
    COLOR_BY_EXP_RANGE[years_range] = SECUENTIAL_PALETTE.as_hex()[i]
    
def get_color_by_exp_range(years_range):
    try:
        return COLOR_BY_EXP_RANGE[years_range]
    except KeyError:
        return ''

# %%
highlight_color = PASTEL_PALETTE.as_hex()[0]

df.sample(50).style.format(
    {col: human_format for col in ['monthly_gross_salary', 'monthly_net_salary', 'usd_monthly_gross_salary', 'usd_monthly_net_salary']},
    precision=1,
    na_rep='missing',
).highlight_null(
    color='gray'
).bar(subset=['monthly_gross_salary', 'usd_monthly_gross_salary', 'usd_monthly_net_salary', 'salary_comparison_last_semester'],
      color='green'
).applymap(
    lambda v: f'background-color: {CATEGORICAL_PALETTE.as_hex()[0]};' if v == 'part-time' else f'background-color: {CATEGORICAL_PALETTE.as_hex()[1]};',
    subset=['work_dedication']
).applymap(
    lambda v: f'background-color: {get_color_by_exp_range(v)};',
    subset=['profile_experience_range']
).applymap(
    lambda v: f'background-color: {highlight_color};' if v and salary_in_top_tech(v) else None,
    subset=['list_of_tools_programming_languages']
)
# Out:
# <style type="text/css">
# #T_371e9_row0_col0, #T_371e9_row1_col0, #T_371e9_row2_col0, #T_371e9_row3_col0, #T_371e9_row4_col0, #T_371e9_row5_col0, #T_371e9_row6_col0, #T_371e9_row7_col0, #T_371e9_row9_col0, #T_371e9_row10_col0, #T_371e9_row11_col0, #T_371e9_row12_col0, #T_371e9_row13_col0, #T_371e9_row14_col0, #T_371e9_row15_col0, #T_371e9_row16_col0, #T_371e9_row18_col0, #T_371e9_row19_col0, #T_371e9_row20_col0, #T_371e9_row21_col0, #T_371e9_row22_col0, #T_371e9_row23_col0, #T_371e9_row24_col0, #T_371e9_row25_col0, #T_371e9_row26_col0, #T_371e9_row27_col0, #T_371e9_row28_col0, #T_371e9_row29_col0, #T_371e9_row30_col0, #T_371e9_row31_col0, #T_371e9_row32_col0, #T_371e9_row33_col0, #T_371e9_row34_col0, #T_371e9_row35_col0, #T_371e9_row36_col0, #T_371e9_row37_col0, #T_371e9_row38_col0, #T_371e9_row39_col0, #T_371e9_row40_col0, #T_371e9_row41_col0, #T_371e9_row42_col0, #T_371e9_row43_col0, #T_371e9_row44_col0, #T_371e9_row45_col0, #T_371e9_row46_col0, #T_371e9_row47_col0, #T_371e9_row48_col0, #T_371e9_row49_col0 {
#   background-color: #fc8d62;
# }
# #T_371e9_row0_col1, #T_371e9_row24_col1, #T_371e9_row48_col12, #T_371e9_row48_col14 {
#   width: 10em;
#   background: linear-gradient(90deg, green 9.1%, transparent 9.1%);
# }
# #T_371e9_row0_col10, #T_371e9_row7_col10, #T_371e9_row11_col10, #T_371e9_row13_col10, #T_371e9_row15_col10, #T_371e9_row19_col10, #T_371e9_row21_col10, #T_371e9_row23_col10, #T_371e9_row26_col10, #T_371e9_row35_col10, #T_371e9_row38_col10, #T_371e9_row39_col10, #T_371e9_row41_col10, #T_371e9_row46_col10, #T_371e9_row48_col10, #T_371e9_row49_col10 {
#   width: 10em;
#   background: linear-gradient(90deg, green 75.0%, transparent 75.0%);
# }
# #T_371e9_row0_col12, #T_371e9_row0_col14 {
#   width: 10em;
#   background: linear-gradient(90deg, green 20.7%, transparent 20.7%);
# }
# #T_371e9_row0_col13, #T_371e9_row2_col13, #T_371e9_row3_col13, #T_371e9_row6_col13, #T_371e9_row7_col13, #T_371e9_row9_col13, #T_371e9_row13_col13, #T_371e9_row20_col13, #T_371e9_row23_col13, #T_371e9_row29_col13, #T_371e9_row36_col13, #T_371e9_row39_col13, #T_371e9_row46_col13 {
#   background-color: #8f3371;
# }
# #T_371e9_row0_col16, #T_371e9_row1_col16, #T_371e9_row2_col16, #T_371e9_row3_col16, #T_371e9_row4_col16, #T_371e9_row5_col16, #T_371e9_row6_col16, #T_371e9_row7_col16, #T_371e9_row8_col16, #T_371e9_row9_col16, #T_371e9_row10_col16, #T_371e9_row11_col16, #T_371e9_row12_col16, #T_371e9_row13_col16, #T_371e9_row14_col16, #T_371e9_row15_col16, #T_371e9_row16_col16, #T_371e9_row17_col16, #T_371e9_row18_col16, #T_371e9_row19_col16, #T_371e9_row20_col16, #T_371e9_row21_col16, #T_371e9_row22_col16, #T_371e9_row23_col16, #T_371e9_row24_col16, #T_371e9_row25_col16, #T_371e9_row26_col16, #T_371e9_row27_col16, #T_371e9_row28_col16, #T_371e9_row29_col16, #T_371e9_row30_col16, #T_371e9_row31_col16, #T_371e9_row32_col16, #T_371e9_row33_col16, #T_371e9_row34_col16, #T_371e9_row35_col16, #T_371e9_row36_col16, #T_371e9_row37_col16, #T_371e9_row38_col16, #T_371e9_row39_col16, #T_371e9_row40_col16, #T_371e9_row41_col16, #T_371e9_row42_col16, #T_371e9_row43_col16, #T_371e9_row44_col16, #T_371e9_row45_col16, #T_371e9_row46_col16, #T_371e9_row47_col16, #T_371e9_row48_col16, #T_371e9_row49_col16 {
#   background-color: #a1c9f4;
# }
# #T_371e9_row1_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, green 6.0%, transparent 6.0%);
# }
# #T_371e9_row1_col9, #T_371e9_row3_col6, #T_371e9_row3_col9, #T_371e9_row3_col15, #T_371e9_row4_col6, #T_371e9_row5_col6, #T_371e9_row5_col9, #T_371e9_row5_col11, #T_371e9_row6_col6, #T_371e9_row6_col9, #T_371e9_row7_col11, #T_371e9_row7_col15, #T_371e9_row8_col6, #T_371e9_row8_col9, #T_371e9_row8_col11, #T_371e9_row8_col15, #T_371e9_row9_col6, #T_371e9_row10_col3, #T_371e9_row10_col6, #T_371e9_row10_col11, #T_371e9_row10_col15, #T_371e9_row11_col6, #T_371e9_row12_col9, #T_371e9_row13_col3, #T_371e9_row13_col6, #T_371e9_row13_col11, #T_371e9_row13_col15, #T_371e9_row14_col6, #T_371e9_row14_col15, #T_371e9_row15_col6, #T_371e9_row15_col11, #T_371e9_row15_col15, #T_371e9_row16_col9, #T_371e9_row17_col6, #T_371e9_row17_col11, #T_371e9_row18_col6, #T_371e9_row19_col6, #T_371e9_row20_col9, #T_371e9_row21_col6, #T_371e9_row21_col9, #T_371e9_row22_col6, #T_371e9_row22_col9, #T_371e9_row23_col9, #T_371e9_row24_col6, #T_371e9_row24_col9, #T_371e9_row25_col6, #T_371e9_row25_col11, #T_371e9_row26_col3, #T_371e9_row26_col6, #T_371e9_row26_col11, #T_371e9_row27_col3, #T_371e9_row27_col6, #T_371e9_row27_col9, #T_371e9_row27_col15, #T_371e9_row28_col9, #T_371e9_row29_col6, #T_371e9_row29_col11, #T_371e9_row31_col9, #T_371e9_row32_col6, #T_371e9_row32_col9, #T_371e9_row33_col6, #T_371e9_row34_col9, #T_371e9_row35_col3, #T_371e9_row35_col6, #T_371e9_row35_col15, #T_371e9_row36_col6, #T_371e9_row36_col9, #T_371e9_row36_col15, #T_371e9_row37_col9, #T_371e9_row38_col6, #T_371e9_row40_col9, #T_371e9_row41_col3, #T_371e9_row41_col6, #T_371e9_row41_col9, #T_371e9_row41_col15, #T_371e9_row43_col15, #T_371e9_row44_col3, #T_371e9_row45_col4, #T_371e9_row45_col6, #T_371e9_row45_col7, #T_371e9_row46_col6, #T_371e9_row46_col9, #T_371e9_row47_col9, #T_371e9_row48_col3, #T_371e9_row48_col6, #T_371e9_row48_col11, #T_371e9_row49_col6, #T_371e9_row49_col15 {
#   background-color: gray;
# }
# #T_371e9_row1_col10, #T_371e9_row2_col10, #T_371e9_row5_col10, #T_371e9_row6_col10, #T_371e9_row9_col10, #T_371e9_row17_col10, #T_371e9_row25_col10, #T_371e9_row47_col10 {
#   width: 10em;
#   background: linear-gradient(90deg, green 25.0%, transparent 25.0%);
# }
# #T_371e9_row1_col12, #T_371e9_row1_col14 {
#   width: 10em;
#   background: linear-gradient(90deg, green 8.2%, transparent 8.2%);
# }
# #T_371e9_row1_col13, #T_371e9_row8_col13, #T_371e9_row17_col13, #T_371e9_row26_col13, #T_371e9_row37_col13, #T_371e9_row42_col13, #T_371e9_row45_col13, #T_371e9_row48_col13 {
#   background-color: #e3685c;
# }
# #T_371e9_row2_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, green 11.3%, transparent 11.3%);
# }
# #T_371e9_row2_col12, #T_371e9_row2_col14, #T_371e9_row9_col12, #T_371e9_row9_col14 {
#   width: 10em;
#   background: linear-gradient(90deg, green 15.8%, transparent 15.8%);
# }
# #T_371e9_row3_col1, #T_371e9_row29_col12, #T_371e9_row29_col14, #T_371e9_row40_col12, #T_371e9_row40_col14 {
#   width: 10em;
#   background: linear-gradient(90deg, green 15.0%, transparent 15.0%);
# }
# #T_371e9_row3_col10, #T_371e9_row7_col12, #T_371e9_row7_col14, #T_371e9_row10_col10, #T_371e9_row12_col10, #T_371e9_row20_col10, #T_371e9_row22_col10, #T_371e9_row29_col1, #T_371e9_row40_col10, #T_371e9_row44_col10, #T_371e9_row45_col10 {
#   width: 10em;
#   background: linear-gradient(90deg, green 100.0%, transparent 100.0%);
# }
# #T_371e9_row3_col12, #T_371e9_row3_col14 {
#   width: 10em;
#   background: linear-gradient(90deg, green 30.9%, transparent 30.9%);
# }
# #T_371e9_row4_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, green 4.1%, transparent 4.1%);
# }
# #T_371e9_row4_col10, #T_371e9_row8_col10, #T_371e9_row14_col10, #T_371e9_row16_col10, #T_371e9_row18_col10, #T_371e9_row24_col10, #T_371e9_row27_col10, #T_371e9_row28_col10, #T_371e9_row29_col10, #T_371e9_row30_col10, #T_371e9_row31_col10, #T_371e9_row32_col10, #T_371e9_row33_col10, #T_371e9_row34_col10, #T_371e9_row36_col10, #T_371e9_row37_col10, #T_371e9_row42_col10, #T_371e9_row43_col10 {
#   width: 10em;
#   background: linear-gradient(90deg, green 50.0%, transparent 50.0%);
# }
# #T_371e9_row4_col12, #T_371e9_row33_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, green 5.7%, transparent 5.7%);
# }
# #T_371e9_row4_col13, #T_371e9_row5_col13, #T_371e9_row16_col13, #T_371e9_row25_col13, #T_371e9_row49_col13 {
#   background-color: #e98d6b;
# }
# #T_371e9_row4_col14 {
#   width: 10em;
#   background: linear-gradient(90deg, green 5.6%, transparent 5.6%);
# }
# #T_371e9_row5_col1, #T_371e9_row45_col1, #T_371e9_row47_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, green 4.8%, transparent 4.8%);
# }
# #T_371e9_row5_col12, #T_371e9_row5_col14, #T_371e9_row16_col12, #T_371e9_row16_col14 {
#   width: 10em;
#   background: linear-gradient(90deg, green

# %%
df = df[columns_of_interest]

# %%
df.to_csv('preprocessed_salaries_dataset.csv', index=False)
